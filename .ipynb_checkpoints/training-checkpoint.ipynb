# %%
import nltk , re

# %%
# from nltk.corpus import PlaintextCorpusReader
# corpus_root = '/Users/ASUS/Documents/txt_mining project/files'

# %%
# files = PlaintextCorpusReader(corpus_root, '.*', encoding='latin-1')
# files.fileids()
# files.sents(fileids="new1.html")

# %%
# print(files.fileids())

# %%
from bs4 import BeautifulSoup
url ='C:\\Users\\ASUS\\Documents\\txt_mining project\\files\\new1.html'
html = open(url, encoding='latin-1')
soup = BeautifulSoup(html,"lxml").get_text() ##contains XML document that recognizes all of the line breaks and white spaces from the original HTML.

# %%
print (soup)
# Out:
# Nieves v. Secretary, DOC
#
#
# Description
#  ORDER denying  1  Petition for writ of habeas corpus and dismissing case with prejudice; clerk is directed to enter judgment accordingly and close the case. Signed by Judge Gregory A. Presnell on 8/20/2009. (TKW)
#
#
#
#                           UNITED STATES DISTRICT COURT
#                            MIDDLE DISTRICT OF FLORIDA
#                                ORLANDO DIVISION
#
# FABIO NIEVES,
#
#       Petitioner,
#
# v.                                                      CASE NO. 6:08-cv-1282-Orl-31DAB
#
# SECRETARY, DEPARTMENT OF
# CORRECTIONS, et al.,
#
#       Respondents.
#
#
#
# TRUE	TITLE	                                         ORDER
#
# Petitioner initiated this action for habeas corpus relief pursuant to 28 U.S.C. section
#
# 2254 (Doc. No. 1). Respondents filed a response to the petition in compliance with this
#
# Court's instructions and with the Rules Governing Section 2254 Cases in the United States
#
# District Courts (Doc. No. 9). Petitioner filed a reply and an amended reply to the response
#
# (Doc. Nos. 12 & 14).
#
# FALSE	NONE	Petitioner alleges one claim for relief in his petition, newly discovered evidence
#
# demonstrates his actual innocence.
#
# TRUE	Procedural History	        I.    Procedural History
#
# FALSE	NONE	      Petitioner was charged by indictment with one count of first degree murder. A jury
#
# trial was conducted in May of 1999, after which Petitioner was found guilty as charged.
#
# The state trial court sentenced Petitioner to a term of life imprisonment. Petitioner
#
# appealed, and the Fifth District Court of Appeal of Florida affirmed on July 9, 1999. See
# Nieves v. State, 739 So. 2d 125 (Fla. 5th DCA 1999). Petitioner filed a motion for rehearing,
#
# which was denied on August 17, 1999. (App. A at 85.) Petitioner filed a notice to invoke
#
# discretionary jurisdiction of the Supreme Court of Florida, which denied the request on
#
# January 18, 2000. Id. at 88.
#
# FALSE	NONE	       Petitioner filed a Florida Rule of Criminal Procedure 3.850 motion for post-
#
# conviction relief on January 16, 2002.1 (App. D at 14.) The state trial court summarily
#
# denied the motion without prejudice. Id. at 56-57. Petitioner filed a notice of supplemental
#
# appellate record and reassertion of motion for post-conviction relief. Id. at 58-60. The state
#
# trial court summarily denied the Rule 3.850 motion on June 14, 2004.               Id. at 87-94.
#
# Petitioner appealed, and the Fifth District Court of Appeal affirmed per curiam on
#
# November 2, 2004. Id. at 282. Mandate was issued on November 19, 2004. Id. at 283.
#
# FALSE	NONE	       On November 30, 2006, Petitioner filed a second Rule 3.850 motion, based on newly
#
# discovered evidence. (App. E at 15.) The state trial court denied the motion, and Petitioner
#
# appealed. The Fifth District Court of Appeal affirmed per curiam on May 13, 2008. Id. at
#
# 154. Mandate was issued on July 7, 2008. Id. at 160.
#
#
#
#
#
# FALSE	NONE	        This is the filing date under the âmailbox rule.â See Thompson v. State, 761 So. 2d
# 324, 326 (Fla. 2000) (â[W]e will presume that a legal document submitted by an inmate is
# timely filed if it contains a certificate of service showing that the pleading was placed in the
# hands of prison or jail officials for mailing on a particular date, if that the pleading would
# be timely filed if it had been received and file-stamped by the Court on that particular
# date.â). All further references to the filing date of pleadings by Petitioner shall be the filing
# date under the mailbox rule, unless otherwise noted.
#
# FALSE	NONE	                                               2
#
# TRUE	Standard	        II.    Legal Standards
#
# TRUE	Procedural Default	       A.     Exhaustion and Procedural Default
#
# FALSE	NONE	       One procedural requirement set forth in the AEDPA precludes federal courts, absent
#
# exceptional circumstances, from granting habeas relief unless the petitioner has exhausted
#
# all means of available relief under state law. 28 U.S.C. Â§ 2254(b); OâSullivan v. Boerckel, 526
#
# U.S. 838, 842-22 (1999); Picard v. Connor, 404 U.S. 270, 275 (1971). Specifically, the AEDPA
#
# provides, in pertinent part:
#
# FALSE	NONE	       An application for a writ of habeas corpus on behalf of a person in custody
#        pursuant to the judgment of a State court shall not be granted unless it
#        appears thatâ
#
# FALSE	NONE	             (A)    the applicant has exhausted the remedies available in the
#                      courts of the State; or
#
# FALSE	NONE	              (B)    (i)       there is an absence of available State corrective process;
#                                or
#
# FALSE	NONE	                     (ii)      circumstances exist that render such process ineffective
#                                to protect the rights of the applicant.
#
# 28 U.S.C. Â§ 2254(b)(1).
#
# FALSE	NONE	       Thus, a federal court must dismiss those claims or portions of claims that have been
#
# denied on adequate and independent procedural grounds under state law. Coleman v.
#
# Thompson, 501 U.S. 722, 750 (1991). In addition, a federal habeas court is precluded from
#
# considering claims that are not exhausted but would clearly be barred if returned to state
#
# court. Id. at 735 n.1 (stating that if the petitioner failed to exhaust state remedies and the
#
# court to which the petitioner would be required to present his claims in order to meet the
#
# exhaustion requirement would now find the claims procedurally barred, there is a
#
# FALSE	NONE	                                                3
#
# procedural default for federal habeas purposes regardless of the decision of the last state
#
# court to which the petitioner actually presented his claims).
#
# FALSE	NONE	       In order to satisfy the exhaustion requirement, a state petitioner must âfairly
#
# presen[t] federal claims to the state courts in order to give the State the opportunity to pass
#
# upon and correct alleged violations of its prisonersâ federal rights.â Duncan v. Henry, 513
#
# U.S. 364, 365 (1995) (citing Picard, 404 U.S. at 275-76) (internal quotation marks omitted).
#
# The petitioner must apprise the state court of the federal constitutional issue, not just the
#
# underlying facts of the claim or a similar state law claim. Snowden v. Singletary, 135 F.3d
#
# 732 (11th Cir. 1998). The United States Supreme Court has observed that âCongress surely
#
# meant that exhaustion be serious and meaningful.â Keeney v. Tamayo-Reyes, 504 U.S. 1, 10
#
# (1992). Furthermore, the Court explained:
#
# FALSE	NONE	       [c]omity concerns dictate that the requirement of exhaustion is not satisfied
#        by the mere statement of a federal claim in state court. Just as the State must
#        afford the petitioner a full and fair hearing on his federal claim, so must the
#        petitioner afford the State a full and fair opportunity to address and resolve
#        the claims on the merits.
#
# Id.; see also Henderson v. Campbell, 353 F.3d 880, 898 n.25 (11th Cir. 2003) (âBoth the legal
#
# theory and the facts on which the federal claim rests must be substantially the same for it
#
# to be the substantial equivalent of the properly exhausted claim.â).
#
# FALSE	NONE	       Procedural default will be excused only in two narrow circumstances. First, a
#
# petitioner may obtain federal review of a procedurally defaulted claim if he can show both
#
# âcauseâ for the default and actual âprejudiceâ resulting from the default. âTo establish
#
# âcauseâ for procedural default, a petitioner must demonstrate that some objective factor
#
#
# FALSE	NONE	                                             4
#
# external to the defense impeded the effort to raise the claim properly in the state court.â
#
# Wright v. Hopper, 169 F.3d 695, 703 (11th Cir. 1999). To establish âprejudice,â a petitioner
#
# must show that there is at least a reasonable probability that the result of the proceeding
#
# would have been different. Henderson, 353 F.3d at 892 (citations omitted).
#
# FALSE	NONE	       The second exception, known as the âfundamental miscarriage of justice,â only
#
# occurs in an extraordinary case, where a âconstitutional violation has probably resulted in
#
# the conviction of one who is actually innocent.â Murray v. Carrier, 477 U.S. 478, 496 (1986).
#
# Actual innocence means factual innocence, not legal insufficiency. Bousley v. United States,
#
# 523 U.S. 614, 623 (1998). To meet this standard, a petitioner must âshow that it is more
#
# likely than not that no reasonable juror would have convicted himâ of the underlying
#
# offense. Schlup v. Delo, 513 U.S. 298, 327 (1995). In addition, ââ[t]o be credible,â a claim of
#
# actual innocence must be based on [new] reliable evidence not presented at trial.â Calderon
#
# v. Thompson, 523 U.S. 538, 559 (1998) (quoting Schlup, 513 U.S. at 324).
#
# TRUE	Standard of Review	       B.     Standard of Review Under the Antiterrorism Effective Death Penalty Act
#               (âAEDPAâ)
#
# FALSE	NONE	       Pursuant to the AEDPA, federal habeas relief may not be granted with respect to a
#
# claim adjudicated on the merits in state court unless the adjudication of the claim:
#
# FALSE	NONE	       (1)    resulted in a decision that was contrary to, or involved an
#               unreasonable application of, clearly established Federal law, as
#               determined by the Supreme Court of the United States; or
#
# FALSE	NONE	       (2)    resulted in a decision that was based on an unreasonable
#               determination of the facts in light of the evidence presented in the
#               State court proceeding.
#
#
#
# FALSE	NONE	                                              5
#
# 28 U.S.C. Â§ 2254(d). The phrase âclearly established Federal law,â encompasses only the
#
# holdings of the United States Supreme Court âas of the time of the relevant state-court
#
# decision.â Williams v. Taylor, 529 U.S. 362, 412 (2000).
#
# FALSE	NONE	       â[S]ection 2254(d)(1) provides two separate bases for reviewing state court decisions;
#
# the âcontrary toâ and âunreasonable applicationâ clauses articulate independent
#
# considerations a federal court must consider.â Maharaj v. Secretary for Depât. of Corr., 432
#
# F.3d 1292, 1308 (11th Cir. 2005). The meaning of the clauses was discussed by the Eleventh
#
# Circuit Court of Appeals in Parker v. Head, 244 F.3d 831, 835 (11th Cir. 2001):
#
# FALSE	NONE	       Under the âcontrary toâ clause, a federal court may grant the writ if the state
#        court arrives at a conclusion opposite to that reached by [the United States
#        Supreme Court] on a question of law or if the state court decides a case
#        differently than [the United States Supreme Court] has on a set of materially
#        indistinguishable facts. Under the âunreasonable applicationâ clause, a
#        federal habeas court may grant the writ if the state court identifies the correct
#        governing legal principle from [the United States Supreme Courtâs] decisions
#        but unreasonably applies that principle to the facts of the prisoner's case.
#
# Even if the federal court concludes that the state court applied federal law incorrectly,
#
# habeas relief is appropriate only if that application was âobjectively unreasonable.â2 Id.
#
# FALSE	NONE	       Finally, under Â§ 2254(d)(2), a federal court may grant a writ of habeas corpus if the
#
# state courtâs decision âwas based on an unreasonable determination of the facts in light of
#
#
#
# FALSE	NONE	        In considering the âunreasonable applicationâinquiry, the Court must determine
# âwhether the state court's application of clearly established federal law was objectively
# unreasonable.â Williams, 529 U.S. at 409. Whether a state court's decision was an
# unreasonable application of law must be assessed in light of the record before the state
# court. Holland v. Jackson, 542 U.S. 649, 652 (2004) (per curiam); cf. Bell v. Cone, 535 U.S. 685,
# 697 n. 4 (2002) (declining to consider evidence not presented to state court in determining
# whether its decision was contrary to federal law).
#
# FALSE	NONE	                                               6
#
# the evidence presented in the State court proceeding.â A determination of a factual issue
#
# made by a state court, however, shall be presumed correct, and the habeas petitioner shall
#
# have the burden of rebutting the presumption of correctness by clear and convincing
#
# evidence. See Parker, 244 F.3d at 835-36; 28 U.S.C. Â§ 2254(e)(1).
#
# TRUE	Analysis	        III.   Analysis
#
# FALSE	NONE	       Petitioner asserts that newly discovered evidence exculpates him of first degree
#
# murder.    In support of his claim, Petitioner relies on the affidavits of Joel Rodriguez
#
# (âRodriguezâ) and Waldemar Viruet (âViruetâ), prison inmates. Specifically, Rodriguez
#
# attested on December 14, 2005, that while he was incarcerated at the Orange County Jail
#
# between July and September of 1998, Joel Sierra (âSierraâ) told him that (1) he saw
#
# Petitioner running away from the victim who was lying on the ground, (2) he saw the
#
# victim try to get up, and (3) he (Sierra) shot the victim because he thought the victim might
#
# shoot Petitioner and the victim appeared to be suffering. See Doc. No. 1 at 23-25. According
#
# to Rodriguez, Sierra said that he knew Petitioner had been convicted for the murder. Id.
#
# at 25. Viruet attested on December 17, 2006, that he observed the events surrounding the
#
# murder from across the street from the McDonaldâs where the offense occurred. Id. at 27-
#
# 28. According to Viruet, he recognized Petitioner as one of the guys involved in the fight,
#
# and although he could not hear what was said, Viruet saw the victim attack Petitioner, and
#
# as they started to fall to the ground, the gun went off. Id. at 27. Viruet attested that he saw
#
# Petitioner get to his feet and run away after which he observed another man approach the
#
# victim, who was rolling around on the ground, and shoot the victim. Id. at 28.
#
#
# FALSE	NONE	                                              7
#
# FALSE	NONE	       Respondents assert that Petitionerâs claim is procedurally barred from review
#
# because it was not raised as a federal claim in the state courts. The record demonstrates
#
# that the instant claim was not raised as a federal constitutional claim in the state courts.
#
# Petitioner cited only to state cases in support of his claim, and all of his substantive
#
# arguments addressed Florida law. Nothing in the claim, therefore, would have alerted the
#
# state court to the presence of a federal claim. Thus, this claim was not exhausted and is
#
# procedurally barred absent application of one of the exceptions.
#
# FALSE	NONE	       In the present case, Petitioner has not shown either cause or prejudice that would
#
# excuse the default. Likewise, Petitioner has not shown the applicability of the fundamental
#
# miscarriage of justice exception. To the extent Petitioner relies on the affidavits of
#
# Rodriguez and Viruet to establish the application of the fundamental miscarriage of justice
#
# exception, the Court concludes that this evidence is not reliable and Petitioner has not
#
# demonstrated that it is more likely than not that no reasonable juror would have convicted
#
# him given this evidence.
#
# FALSE	NONE	       First, both Rodriguez and Viruet, who are inmates, provided Petitioner with
#
# statements more than six years after Petitionerâs trial. Neither of them notified law
#
# enforcement at any point of what they saw on the night of the incident or heard regarding
#
# the incident. Moreover, the statements contained in Rodriguezâs affidavit that Sierra
#
# admitted shooting the victim after Petitioner fled are hearsay statements. For these
#
# reasons, the Court cannot find that Petitionerâs newly discovered evidence is reliable.
#
#
#
#
# FALSE	NONE	                                             8
#
# FALSE	NONE	       Moreover, even assuming that the newly discovered evidence were reliable, the
#
# evidence presented at trial refutes the application of the actual innocence exception. At
#
# trial, Todd Wexler (âWexlerâ) testified that he saw Petitioner shoot the victim four times
#
# in rapid succession.3 (App. B at 339, 360, 365.) Wexler further testified that after Petitioner
#
# shot the victim and Petitioner and the others who were near the victim ran away, Wexler
#
# immediately walked to the victim. Id. at 340, 359. Wexler stated that he heard two shots
#
# prior to Petitioner shooting the victim, but Wexler did not indicate that he heard or saw
#
# any shots fired after he saw Petitioner shoot the victim. Id. at 385, 387.
#
# FALSE	NONE	       Bruno Goncalves (âGoncalvesâ) also testified that he saw Petitioner shoot the victim
#
# four times in rapid succession. (App. B at 393, 402, 410-11.) Like Wexler, Goncalves
#
# testified that he (Goncalves) went to the victim immediately after the victim was shot. Id.
#
# at 394. Goncalves testified that he heard one gunshot in the McDonaldâs parking lot prior
#
# to the victim being shot, but Goncalves did not indicate that he saw or heard any shots
#
# fired after Petitioner shot the victim. Id. at 401.
#
# FALSE	NONE	       Wexler and Goncalvesâ testimony that they went to the victim after they saw
#
# Petitioner shoot the victim refutes the affidavits of Rodriguez and Viruet wherein they state
#
# that another person shot the victim after Petitioner fled. In addition to Wexler and
#
# Goncalves testimony, Charles Lopez (âLopezâ) testified that he was with Petitioner at the
#
# time of the incident and that Petitioner told him after they left the scene of the offense that
#
#
# FALSE	NONE	       Wexler testified that he did not identify Petitioner as the shooter on the date of the
# incident but identified him a few days later after he had seen a news report on the incident
# in which Petitioner was identified as a suspect.
#
# FALSE	NONE	                                               9
#
# he âbucked that niggerâ and made three hand motions in conjunction with the statement.
#
# Id. at 433. Lopez stated that Petitioner told him that the victim said âauâ three times while
#
# Petitioner was shooting him. Id. at 435. Additionally, Detective Linnert testified that
#
# Petitioner admitted that he shot the victim in self defense three times while the victim was
#
# on the ground and was kicking Petitionerâs legs. Finally, the evidence established that the
#
# bullet casings found around or in close proximity to the victim were from Petitionerâs 9
#
# millimeter gun. For all of these reasons, the Court concludes that Petitioner has not
#
# established the applicability of the manifest miscarriage of justice exception to overcome
#
# the procedural default bar, and this claim is procedurally barred.
#
# FALSE	NONE	       Furthermore, the Court notes that a claim of actual innocence based on newly
#
# discovered evidence is not cognizable in habeas proceedings because federal habeas relief
#
# is designed to rectify constitutional violations, rather than factual errors. See Herrera v.
#
# Collins, 506 U.S. 390, 390-91 (1993) (â[C]laims of actual innocence based on newly
#
# discovered evidence have never been held to state a ground for federal habeas relief absent
#
# an independent constitutional violation occurring in the course of the underlying state
#
# criminal proceedings.â); Townsend v. Sain, 372 U.S. 293 (1963) (â[T]he existence merely of
#
# newly discovered evidence relevant to the guilt of a state prisoner is not ground for relief
#
# on federal habeas corpus.â); Jordan v. Secretary, Dept. of Corrections, 485 F.3d 1351, 1356 (11th
#
# Cir. 2007) (âFor what it is worth, our precedent forbids granting habeas relief based upon
#
# a claim of actual innocence, anyway, at least in non-capital cases.â); Drake v. Francis, 727
#
# F.2d 990, 993 (11th Cir. 1984) (âIn order for a claim of newly discovered evidence to justify
#
#
# FALSE	NONE	                                               10
#
# habeas review, the evidence must bear on the constitutionality of the defendantâs
#
# conviction.â). Petitioner did not assert in the state court that a constitutional violation
#
# occurred in the course of his trial. Petitioner summarily asserts in his memorandum in
#
# support of the instant habeas petition that his Sixth and Fourteenth Amendment rights âto
#
# a full and fair trial and/or postconviction review was denied by the state courtâs failure to
#
# consider the new evidence of innocence in state postconviction proceedings against the
#
# evidence of guilt by conducting an evidentiary hearing in the state postconviction
#
# proceedings.â (Doc. No. 4 at 8.)      To the extent Petitioner has alleged a constitutional
#
# violation occurred in the state postconviction proceeding, the Court notes that â[a] habeas
#
# petition must allege that the petitionerâs detention violates the constitution, a federal
#
# statute, or a treaty. . . . [A] petition alleging errors in the state post-conviction review
#
# process is not addressable through habeas corpus proceedings.â Franzen v. Brinkman, 877
#
# F.2d 26 (9th Cir. 1989).
#
# FALSE	NONE	       In Spradley v. Dugger, 825 F.2d 1566 (11th Cir. 1987), the petitioner argued that the
#
# state trial court violated his due process rights when it denied his Rule 3.850 motion
#
# because it did not conduct an evidentiary hearing and because its opinion denying relief
#
# failed to attach those portions of the record on which it relied. The Eleventh Circuit Court
#
# of Appeals held that the state trial courtâs alleged errors in the Rule 3.850 proceedings did
#
# not undermine the validity of the petitionerâs conviction; therefore, the claim went to issues
#
# unrelated to the cause of the petitionerâs detention, and it did not state a basis for habeas
#
# relief. Id. at 1567; see also Mitchell v. Wyrick, 727 F.2d 773, 774 (8th Cir. 1984) ( âEven where
#
#
# FALSE	NONE	                                               11
#
# there may be some error in state post-conviction proceedings, this would not entitle
#
# appellant to federal habeas corpus relief since appellantâs claim here represents an attack
#
# on a proceeding collateral to detention of appellant and not on the detention itself.â)
#
# (quotation omitted) (citation omitted). Petitioner alleges error in the state post-conviction
#
# review process which is not addressable through the instant habeas corpus proceeding.
#
# Thus, even if the claim were not procedurally barred, it is not cognizable.
#
# FALSE	NONE	       Finally, even assuming that this claim was not procedurally barred and was
#
# cognizable, the claim would be subject to denial pursuant to Â§ 2254(d). The state trial court
#
# denied relief on Petitionerâs claim of newly discovered evidence. (App. E at 85-88.) In so
#
# ruling, the state court reasoned that Rodriguezâs testimony would not have made a
#
# difference in the outcome of the trial because:
#
# FALSE	NONE	              the medical examiner could not determine the caliber of the
#               bullet that caused the victimâs fatal wound to the heart, but he
#               never indicated that he could determine the caliber of any
#               other bullet that struck the victim. Furthermore, Rodriguez
#               does not mention the caliber of the bullet or even the type of
#               gun Sierra said he used. Finally, while spent casings matching
#               Defendantâs 9mm pistol were found near the victimâs body, the
#               .45 caliber casing was found in a different area. . . .
#
# FALSE	NONE	                    Furthermore, Defendant cannot establish that
#               Rodriguezâs hearsay testimony regarding Sierraâs purported
#               confession would even be admissible. . . .
#
# FALSE	NONE	                      Finally, the victim received another bullet wound that
#               would have probably been fatal, i.e., a bullet pierced his right
#               lung and caused internal bleeding into the chest cavity. Even
#               if Defendant could offer conclusive proof that there was a
#               second shooter and that he himself did not fire the fatal shot,
#               he still could have been convicted of first degree murder as a
#               principal. . . .
#
# FALSE	NONE	                                             12
#
# Id. at 86-87 (citations omitted). As to Viruetâs testimony, the state court reasoned:
#
# FALSE	NONE	               [although] Viruetâs testimony would presumably corroborate
#                Sierraâs confession . . . it would not change the fact that
#                Defendant could still have been convicted of first-degree
#                murder as a principal. Furthermore, there is no reasonable
#                probability that it would support a self-defense theory. It
#                would be inconsistent with Defendantâs own statement that the
#                victim was lying on his back on the pavement when Defendant
#                fired three shots at him. It would also be inconsistent with the
#                testimony of eyewitnesses Joseph Wexler and Bruno
#                Goncalves, who asserted that Defendant walked over and shot
#                the victim after others who had been fighting with him had
#                caused him to end up on the ground.
#
# Id. at 88 (citations omitted).
#
# FALSE	NONE	       Upon review of the record, the Court concludes that Petitioner has failed to
#
# demonstrate by clear and convincing evidence that the state courtâs determination is
#
# unreasonable in light of the evidence presented.            Moreover, Petitioner has not
#
# demonstrated that the state courtâs determination is either contrary to, or an unreasonable
#
# application of, federal law. Accordingly, this claim is subject to denial pursuant to Â§
#
# 2254(d).
#
# FALSE	NONE	       Any of Petitionerâs allegations not specifically addressed herein have been found to
#
# be without merit.
#
# FALSE	NONE	       Accordingly, it is hereby ORDERED AND ADJUDGED:
#
#        1.      The Petition for Writ of Habeas Corpus (Doc. No. 1) filed by Fabio Nieves is
#
# DENIED, and this case is DISMISSED WITH PREJUDICE.
#
#        2.      The Clerk of the Court shall enter judgment accordingly and is directed to
#
# close this case.
#
# FALSE	NONE	                                             13
#
# FALSE	NONE	      DONE AND ORDERED at Orlando, Florida, this 20th day of August, 2009.
#
#
#
#
# Copies to:
# sc 8/20
# Fabio Nieves
# Counsel of Record

# %%
soup
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNieves v. Secretary, DOC\n\n\nDescription\n ORDER denying  1  Petition for writ of habeas corpus and dismissing case with prejudice; clerk is directed to enter judgment accordingly and close the case. Signed by Judge Gregory A. Presnell on 8/20/2009. (TKW)\n\n\n\n                          UNITED STATES DISTRICT COURT\n                           MIDDLE DISTRICT OF FLORIDA\n                               ORLANDO DIVISION\n\nFABIO NIEVES,\n\n      Petitioner,\n\nv.                                                      CASE NO. 6:08-cv-1282-Orl-31DAB\n\nSECRETARY, DEPARTMENT OF\nCORRECTIONS, et al.,\n\n      Respondents.\n\n\n\nTRUE\tTITLE\t                                         ORDER\n\nPetitioner initiated this action for habeas corpus relief pursuant to 28 U.S.C. section\n\n2254 (Doc. No. 1). Respondents filed a response to the petition in compliance with this\n\nCourt's instructions and with the Rules Governing Section 2254 Cases in the United States\n\nDistrict Courts (Doc. No. 9). Petitioner filed a reply and an amended reply to the response\n\n(Doc. Nos. 12 & 14).\n\nFALSE\tNONE\tPetitioner alleges one claim for relief in his petition, newly discovered evidence\n\ndemonstrates his actual innocence.\n\nTRUE\tProcedural History\t        I.    Procedural History\n\nFALSE\tNONE\t      Petitioner was charged by indictment with one count of first degree murder. A jury\n\ntrial was conducted in May of 1999, after which Petitioner was found guilty as charged.\n\nThe state trial court sentenced Petitioner to a term of life imprisonment. Petitioner\n\nappealed, and the Fifth District Court of Appeal of Florida affirmed on July 9, 1999. See\nNieves v. State, 739 So. 2d 125 (Fla. 5th DCA 1999). Petitioner filed a motion for rehearing,\n\nwhich was denied on August 17, 1999. (App. A at 85.) Petitioner filed a notice to invoke\n\ndiscretionary jurisdiction of the Supreme Court of Florida, which denied the request on\n\nJanuary 18, 2000. Id. at 88.\n\nFALSE\tNONE\t       Petitioner filed a Florida Rule of Criminal Procedure 3.850 motion for post-\n\nconviction relief on January 16, 2002.1 (App. D at 14.) The state trial court summarily\n\ndenied the motion without prejudice. Id. at 56-57. Petitioner filed a notice of supplemental\n\nappellate record and reassertion of motion for post-conviction relief. Id. at 58-60. The state\n\ntrial court summarily denied the Rule 3.850 motion on June 14, 2004.               Id. at 87-94.\n\nPetitioner appealed, and the Fifth District Court of Appeal affirmed per curiam on\n\nNovember 2, 2004. Id. at 282. Mandate was issued on November 19, 2004. Id. at 283.\n\nFALSE\tNONE\t       On November 30, 2006, Petitioner filed a second Rule 3.850 motion, based on newly\n\ndiscovered evidence. (App. E at 15.) The state trial court denied the motion, and Petitioner\n\nappealed. The Fifth District Court of Appeal affirmed per curiam on May 13, 2008. Id. at\n\n154. Mandate was issued on July 7, 2008. Id. at 160.\n\n\n\n\n\nFALSE\tNONE\t        This is the filing date under the â\x80\x9cmailbox rule.â\x80\x9d See Thompson v. State, 761 So. 2d\n324, 326 (Fla. 2000) (â\x80\x9c[W]e will presume that a legal document submitted by an inmate is\ntimely filed if it contains a certificate of service showing that the pleading was placed in the\nhands of prison or jail officials for mailing on a particular date, if that the pleading would\nbe timely filed if it had been received and file-stamped by the Court on that particular\ndate.â\x80\x9d). All further references to the filing date of pleadings by Petitioner shall be the filing\ndate under the mailbox rule, unless otherwise noted.\n\nFALSE\tNONE\t                                               2\n\nTRUE\tStandard\t        II.    Legal Standards\n\nTRUE\tProcedural Default\t       A.     Exhaustion and Procedural Default\n\nFALSE\tNONE\t       One procedural requirement set forth in the AEDPA precludes federal cou ...

# %%
#re.sub('..[\\n].',' ',soup) #this line to eliminate \n but not \n\n -->doesn't seems to be useful

# %%
soup=soup.lstrip('\n').rstrip('\n')

# %%
para= soup.split(sep='\n')

# %%
para
# Out:
# ['Nieves v. Secretary, DOC',
#  '',
#  '',
#  'Description',
#  ' ORDER denying  1  Petition for writ of habeas corpus and dismissing case with prejudice; clerk is directed to enter judgment accordingly and close the case. Signed by Judge Gregory A. Presnell on 8/20/2009. (TKW)',
#  '',
#  '',
#  '',
#  '                          UNITED STATES DISTRICT COURT',
#  '                           MIDDLE DISTRICT OF FLORIDA',
#  '                               ORLANDO DIVISION',
#  '',
#  'FABIO NIEVES,',
#  '',
#  '      Petitioner,',
#  '',
#  'v.                                                      CASE NO. 6:08-cv-1282-Orl-31DAB',
#  '',
#  'SECRETARY, DEPARTMENT OF',
#  'CORRECTIONS, et al.,',
#  '',
#  '      Respondents.',
#  '',
#  '',
#  '',
#  'TRUE\tTITLE\t                                         ORDER',
#  '',
#  'Petitioner initiated this action for habeas corpus relief pursuant to 28 U.S.C. section',
#  '',
#  '2254 (Doc. No. 1). Respondents filed a response to the petition in compliance with this',
#  '',
#  "Court's instructions and with the Rules Governing Section 2254 Cases in the United States",
#  '',
#  'District Courts (Doc. No. 9). Petitioner filed a reply and an amended reply to the response',
#  '',
#  '(Doc. Nos. 12 & 14).',
#  '',
#  'FALSE\tNONE\tPetitioner alleges one claim for relief in his petition, newly discovered evidence',
#  '',
#  'demonstrates his actual innocence.',
#  '',
#  'TRUE\tProcedural History\t        I.    Procedural History',
#  '',
#  'FALSE\tNONE\t      Petitioner was charged by indictment with one count of first degree murder. A jury',
#  '',
#  'trial was conducted in May of 1999, after which Petitioner was found guilty as charged.',
#  '',
#  'The state trial court sentenced Petitioner to a term of life imprisonment. Petitioner',
#  '',
#  'appealed, and the Fifth District Court of Appeal of Florida affirmed on July 9, 1999. See',
#  'Nieves v. State, 739 So. 2d 125 (Fla. 5th DCA 1999). Petitioner filed a motion for rehearing,',
#  '',
#  'which was denied on August 17, 1999. (App. A at 85.) Petitioner filed a notice to invoke',
#  '',
#  'discretionary jurisdiction of the Supreme Court of Florida, which denied the request on',
#  '',
#  'January 18, 2000. Id. at 88.',
#  '',
#  'FALSE\tNONE\t       Petitioner filed a Florida Rule of Criminal Procedure 3.850 motion for post-',
#  '',
#  'conviction relief on January 16, 2002.1 (App. D at 14.) The state trial court summarily',
#  '',
#  'denied the motion without prejudice. Id. at 56-57. Petitioner filed a notice of supplemental',
#  '',
#  'appellate record and reassertion of motion for post-conviction relief. Id. at 58-60. The state',
#  '',
#  'trial court summarily denied the Rule 3.850 motion on June 14, 2004.               Id. at 87-94.',
#  '',
#  'Petitioner appealed, and the Fifth District Court of Appeal affirmed per curiam on',
#  '',
#  'November 2, 2004. Id. at 282. Mandate was issued on November 19, 2004. Id. at 283.',
#  '',
#  'FALSE\tNONE\t       On November 30, 2006, Petitioner filed a second Rule 3.850 motion, based on newly',
#  '',
#  'discovered evidence. (App. E at 15.) The state trial court denied the motion, and Petitioner',
#  '',
#  'appealed. The Fifth District Court of Appeal affirmed per curiam on May 13, 2008. Id. at',
#  '',
#  '154. Mandate was issued on July 7, 2008. Id. at 160.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'FALSE\tNONE\t        This is the filing date under the â\x80\x9cmailbox rule.â\x80\x9d See Thompson v. State, 761 So. 2d',
#  '324, 326 (Fla. 2000) (â\x80\x9c[W]e will presume that a legal document submitted by an inmate is',
#  'timely filed if it contains a certificate of service showing that the pleading was placed in the',
#  'hands of prison or jail officials for mailing on a particular date, if that the pleading would',
#  'be timely filed if it had been received and file-stamped by the Court on that particular',
#  'date.â\x80\x9d). All further references to the filing date of pleadings by Petitioner shall be the filing',
#  'date under the mailbox rule, unless otherwise noted.',
#  '',
#  'FALSE\tNONE\t                                               2',
#  '',
#  'TRUE\tStandard\t        II.    Legal Standards',
#  '',
#  'TRUE\tProcedural Default\t       A.     Exhaustion and Procedural Default',
#  '',
#  'FALSE\tNONE\t       One procedural requirement set forth in the AEDPA precludes federal courts, absent',
#  '',
#  'exceptional circumstances, from granting habeas relief unless the petitioner has exhausted',
#  '',
#  'all means of available relief under state law. 28 U.S.C. Â§ 2254(b); Oâ\x80\x99Sullivan v. Boerckel, 526',
#  '',
#  'U.S. 838, 842-22 (1999); Picard v. Connor, 404 U.S. 270, 275 (1971). Specifically, the AEDPA',
#  '',
#  'provides, in pertinent part:',
#  '',
#  'FALSE\tNONE\t       An application for a writ of habeas corpus on behalf of a person in custody',
#  '       pursuant to the judgment of a State court shall not be granted unless it',
#  '       appears thatâ\x80\x93',
#  '',
#  'FALSE\tNONE\t             (A)    the applicant has exhausted the remedies available in the',
#  '                     courts of the State; or',
#  '',
#  'FALSE\tNONE\t              (B)    (i)       there is an absence of available State corrective process;',
#  '                               or',
#  '',
#  'FALSE\tNONE\t                     (ii)      circumstances exist that render such process ineffective',
#  '                               to protect the rights of the applicant.',
#  '',
#  '28 U.S.C. Â§ 2254(b)(1).',
#  '',
#  'FALSE\tNONE\t       Thus, a federal court must dismiss those claims or portions of claims that have been',
#  '',
#  'denied on adequate and independent procedural grounds under state law. Coleman v.',
#  '',
#  'Thompson, 501 U.S. 722, 750 (1991). In addition, a federal habeas court is precluded from',
#  '',
#  'considering claims that are not exhausted but would clearly be barred if returned to state',
#  '',
#  'court. Id. at 735 n.1 (stating that if the petitioner failed to exhaust state remedies and the',
#  '',
#  'court to which the petitioner would be required to present his claims in order to meet the',
#  '',
#  'exhaustion requirement would now find the claims procedurally barred, there is a',
#  '',
#  'FALSE\tNONE\t                                                3',
#  '',
#  'procedural default for federal habeas purposes regardless of the decision of the last state',
#  '',
#  'court to which the petitioner actually presented his claims).',
#  '',
#  'FALSE\tNONE\t       In order to satisfy the exhaustion requirement, a state petitioner must â\x80\x9cfairly',
#  '',
#  'presen[t] federal claims to the state courts in order to give the State the opportunity to pass',
#  '',
#  'upon and correct alleged violations of its prisonersâ\x80\x99 federal rights.â\x80\x9d Duncan v. Henry, 513',
#  '',
#  'U.S. 364, 365 (1995) (citing Picard, 404 U.S. at 275-76) (internal quotation marks omitted).',
#  '',
#  'The petitioner must apprise the state court of the federal constitutional issue, not just the',
#  '',
#  'underlying facts of the claim or a similar state law claim. Snowden v. Singletary, 135 F.3d',
#  '',
#  '732 (11th Cir. 1998). The United States Supreme Court has observed that â\x80\x9cCongress surely',
#  '',
#  'meant that exhaustion be serious and meaningful.â\x80\x9d Keeney v. Tamayo-Reyes, 504 U.S. 1, 10',
#  '',
#  '(1992). Furthermore, the Court explained:',
#  '',
#  'FALSE\tNONE\t       [c]omity concerns dictate that the requirement of exhaustion is not satisfied',
#  '       by the mere statement of a federal claim in state court. Just as the State must',
#  '       afford the petitioner a full and fair hearing on his federal claim, so must the',
#  '       petitioner afford the State a full and fair opportunity to address and resolve',
#  '       the claims on the merits.',
#  '',
#  'Id.; see also Henderson v. Campbell, 353 F.3d 880, 898 n.25 (11th Cir. 2003) (â\x80\x9cBoth the legal',
#  '',
#  'theory and the facts on which the federal claim rests must be substantially the same for it',
#  '',
#  'to be the substantial equivalent of the properly exhausted claim.â\x80\x9d).',
#  '',
#  'FALSE\tNONE\t       Procedural default will be excused only in two narrow circumstances. First, a',
#  '',
#  'petitioner may obtain federal review of a procedurally defaulted claim if he can show both',
#  '',
#  'â\x80\x9ccauseâ\x80\x9d for the default and actual â\x80\x9cprejudiceâ\x80\x9d resulting from the default. â\x80\x9cTo establish',
#  '',
#  'â\x80\x98causeâ\x80\x99 for procedural default, a petitioner must demonstrate that some objective factor',
#  '',
#  '',
#  'FALSE\tNONE\t                                             4',
#  '',
#  'external to the defense impeded the effort to raise the claim properly in the state court.â\x80\x9d',
#  '',
#  'Wright v. Hopper, 169 F.3d 695, 703 (11th Cir. 1999). To establish â\x80\x9cprejudice,â\x80\x9d a petitioner',
#  '',
#  'must show that there is at least a reasonable probability that the result of the proceeding',
#  '',
#  'would have been different. Henderson, 353 F.3d at 892 (citations omitted).',
#  '',
#  'FALSE\tNONE\t       The second exception, known as the â\x80\x9cfundamental miscarriage of justice,â\x80\x9d only',
#  '',
#  'occurs in an extraordinary case, where a â\x80\x9cconstitutional violation has probably resulted in',
#  '',
#  'the conviction of one who is actually innocent.â\x80\x9d Murray v. Carrier, 477 U.S. 478, 496 (1986).',
#  '',
#  'Actual innocence means factual innocence, not legal insufficiency. Bousley v. United States,',
#  '',
#  '523 U.S. 614, 623 (1998). To meet this standard, a petitioner must â\x80\x9cshow that it is more',
#  '',
#  'likely than not that no reasonable juror would have convicted himâ\x80\x9d of the underlying',
#  '',
#  'offense. Schlup v. Delo, 513 U.S. 298, 327 (1995). In addition, â\x80\x9câ\x80\x98[t]o be credible,â\x80\x99 a claim of',
#  '',
#  'actual innocence must be based on [new] reliable evidence not presented at trial.â\x80\x9d Calderon',
#  '',
#  'v. Thompson, 523 U.S. 538, 559 (1998) (quoting Schlup, 513 U.S. at 324).',
#  '',
#  'TRUE\tStandard of Review\t       B.     Standard of Review Under the Antiterrorism Effective Death Penalty Act',
#  '              (â\x80\x9cAEDPAâ\x80\x9d)',
#  '',
#  'FALSE\tNONE\t       Pursuant to the AEDPA, federal habeas relief may not be granted with respect to a',
#  '',
#  'claim adjudicated on the merits in state court unless the adjudication of the claim:',
#  '',
#  'FALSE\tNONE\t       (1)    resulted in a decision that was contrary to, or involved an',
#  '              unreasonable application of, clearly established Federal law, as',
#  '              determined by the Supreme Court of the United States; or',
#  '',
#  'FALSE\tNONE\t       (2)    resulted in a decision that was based on an unreasonable',
#  '              determination of the facts in light of the evidence presented in the',
#  '              State court proceeding.',
#  '',
#  '',
#  '',
#  'FALSE\tNONE\t                                              5',
#  '',
#  '28 U.S.C. Â§ 2254(d). The phrase â\x80\x9cclearly established Federal law,â\x80\x9d encompasses only the',
#  '',
#  'holdings of the United States Supreme Court â\x80\x9cas of the time of the relevant state-court',
#  '',
#  'decision.â\x80\x9d Williams v. Taylor, 529 U.S. 362, 412 (2000).',
#  '',
#  'FALSE\tNONE\t       â\x80\x9c[S]ection 2254(d)(1) provides two separate bases for reviewing state court decisions;',
#  '',
#  'the â\x80\x98contrary toâ\x80\x99 and â\x80\x98unreasonable applicationâ\x80\x99 clauses articulate independent',
#  '',
#  'considerations a federal court must consider.â\x80\x9d Maharaj v. Secretary for Depâ\x80\x99t. of Corr., 432',
#  '',
#  'F.3d 1292, 1308 (11th Cir. 2005). The meaning of the clauses was discussed by the Eleventh',
#  '',
#  'Circuit Court of Appeals in Parker v. Head, 244 F.3d 831, 835 (11th Cir. 2001):',
#  '',
#  'FALSE\tNONE\t       Under the â\x80\x9ccontrary toâ\x80\x9d clause, a federal court may grant the writ if the state',
#  '       court arrives at a conclusion opposite to that reached by [the United States',
#  '       Supreme Court] on a question of law or if the state court decides a case',
#  '       differently than [the United States Supreme Court] has on a set of materially',
#  '       indistinguishable facts. Under the â\x80\x98unreasonable applicationâ\x80\x99 clause, a',
#  '       federal habeas court may grant the writ if the state court identifies the correct',
#  '       governing legal principle from [the United States Supreme Courtâ\x80\x99s] decisions',
#  "       but unreasonably applies that principle to the facts of the prisoner's case.",
#  '',
#  'Even if the federal court concludes that the state court applied federal law incorrectly,',
#  '',
#  'habeas relief is appropriate only if that application was â\x80\x9cobjectively unreasonable.â\x80\x9d2 Id.',
#  '',
#  'FALSE\tNONE\t       Finally, under Â§ 2254(d)(2), a federal court may grant a writ of habeas corpus if the',
#  '',
#  'state courtâ\x80\x99s decision â\x80\x9cwas based on an unreasonable determination of the facts in light of',
#  '',
#  '',
#  '',
#  'FALSE\tNONE\t        In considering the â\x80\x9cunreasonable applicationâ\x80\x9dinquiry, the Court must determine',
#  "â\x80\x9cwhether the state court's application of clearly established federal law was objectively",
#  "unreasonable.â\x80\x9d Williams, 529 U.S. at 409. Whether a state court's decision was an",
#  'unreasonable application of law must be assessed in light of the record before the state',
#  'court. Holland v. Jackson, 542 U.S. 649, 652 (2004) (per curiam); cf. Bell v. Cone, 535 U.S. 685,',
#  '697 n. 4 (2002) (declining to consider evidence not presented to state court in determining',
#  'whether its decision was contrary to federal law).',
#  '',
#  'FALSE\tNONE\t                                               6',
#  '',
#  'the evidence presented in the State court proceeding.â\x80\x9d A determination of a factual issue',
#  '',
#  'made by a state court, however, shall be presumed correct, and the habeas petitioner shall',
#  '',
#  'have the burden of rebutting the presumption of correctness by clear and convincing',
#  '',
#  'evidence. See Parker, 244 F.3d at 835-36; 28 U.S.C. Â§ 2254(e)(1).',
#  '',
#  'TRUE\tAnalysis\t        III.   Analysis',
#  '',
#  'FALSE\tNONE\t       Petitioner asserts that newly discovered evidence exculpates him of first degree',
#  '',
#  'murder.    In support of his claim, Petitioner relies on the affidavits of Joel Rodriguez',
#  '',
#  '(â\x80\x9cRodriguezâ\x80\x9d) and Waldemar Viruet (â\x80\x9cViruetâ\x80\x9d), prison inmates. Specifically, Rodriguez',
#  '',
#  'attested on December 14, 2005, that while he was incarcerated at the Orange County Jail',
#  '',
#  'between July and September of 1998, Joel Sierra (â\x80\x9cSierraâ\x80\x9d) told him that (1) he saw',
#  '',
#  'Petitioner running away from the victim who was lying on the ground, (2) he saw the',
#  '',
#  'victim try to get up, and (3) he (Sierra) shot the victim because he thought the victim might',
#  '',
#  'shoot Petitioner and the victim appeared to be suffering. See Doc. No. 1 at 23-25. According',
#  '',
#  'to Rodriguez, Sierra said that he knew Petitioner had been convicted for the murder. Id.',
#  '',
#  'at 25. Viruet attested on December 17, 2006, that he observed the events surrounding the',
#  '',
#  'murder from across the street from the McDonaldâ\x80\x99s where the offense occurred. Id. at 27-',
#  '',
#  '28. According to Viruet, he recognized Petitioner as one of the guys involved in the fight,',
#  '',
#  'and although he could not hear what was said, Viruet saw the victim attack Petitioner, and',
#  '',
#  'as they started to fall to the ground, the gun went off. Id. at 27. Viruet attested that he saw',
#  '',
#  'Petitioner get to his feet and run away after which he observed another man approach the',
#  '',
#  'victim, who was rolling around on the ground, and shoot the victim. Id. at 28.',
#  '',
#  '',
#  'FALSE\tNONE\t                                              7',
#  '',
#  'FALSE\tNONE\t       Respondents assert that Petitionerâ\x80\x99s claim is procedurally barred from review',
#  '',
#  'because it was not raised as a federal claim in the state courts. The record demonstrates',
#  '',
#  'that the instant claim was not raised as a federal constitutional claim in the state courts.',
#  '',
#  'Petitioner cited only to state cases in support of his claim, and all of his substantive',
#  '',
#  'arguments addressed Florida law. Nothing in the claim, therefore, would have alerted the',
#  '',
#  'state court to the presence of a federal claim. Thus, this claim was not exhausted and is',
#  '',
#  'procedurally barred absent application of one of the exceptions.',
#  '',
#  'FALSE\tNONE\t       In the present case, Petitioner has not shown either cause or prejudice that would',
#  '',
#  'excuse the default. Likewise, Petitioner has not shown the applicability of the fundamental',
#  '',
#  'miscarriage of justice exception. To the extent Petitioner relies on the affidavits of',
#  '',
#  'Rodriguez and Viruet to establish the application of the fundamental miscarriage of justice',
#  '',
#  'exception, the Court concludes that this evidence is not reliable and Petitioner has not',
#  '',
#  'demonstrated that it is more likely than not that no reasonable juror would have convicted',
#  '',
#  'him given this evidence.',
#  '',
#  'FALSE\tNONE\t       First, both Rodriguez and Viruet, who are inmates, provided Petitioner with',
#  '',
#  'statements more than six years after Petitionerâ\x80\x99s trial. Neither of them notified law',
#  '',
#  'enforcement at any point of what they saw on the night of the incident or heard regarding',
#  '',
#  'the incident. Moreover, the statements contained in Rodriguezâ\x80\x99s affidavit that Sierra',
#  '',
#  'admitted shooting the victim after Petitioner fled are hearsay statements. For these',
#  '',
#  'reasons, the Court cannot find that Petitionerâ\x80\x99s newly discovered evidence is reliable.',
#  '',
#  '',
#  '',
#  '',
#  'FALSE\tNONE\t                                             8',
#  '',
#  'FALSE\tNONE\t       Moreover, even assuming that the newly discovered evidence were reliable, the',
#  '',
#  'evidence presented at trial refutes the application of the actual innocence exception. At',
#  '',
#  'trial, Todd Wexler (â\x80\x9cWexlerâ\x80\x9d) testified that he saw Petitioner shoot the victim four times',
#  '',
#  'in rapid succession.3 (App. B at 339, 360, 365.) Wexler further testified that after Petitioner',
#  '',
#  'shot the victim and Petitioner and the others who were near the victim ran away, Wexler',
#  '',
#  'immediately walked to the victim. Id. at 340, 359. Wexler stated that he heard two shots',
#  '',
#  'prior to Petitioner shooting the victim, but Wexler did not indicate that he heard or saw',
#  '',
#  'any shots fired after he saw Petitioner shoot the victim. Id. at 385, 387.',
#  '',
#  'FALSE\tNONE\t       Bruno Goncalves (â\x80\x9cGoncalvesâ\x80\x9d) also testified that he saw Petitioner shoot the victim',
#  '',
#  'four times in rapid succession. (App. B at 393, 402, 410-11.) Like Wexler, Goncalves',
#  '',
#  'testified that he (Goncalves) went to the victim immediately after the victim was shot. Id.',
#  '',
#  'at 394. Goncalves testified that he heard one gunshot in the McDonaldâ\x80\x99s parking lot prior',
#  '',
#  'to the victim being shot, but Goncalves did not indicate that he saw or heard any shots',
#  '',
#  'fired after Petitioner shot the victim. Id. at 401.',
#  '',
#  'FALSE\tNONE\t       Wexler and Goncalvesâ\x80\x99 testimony that they went to the victim after they saw',
#  '',
#  'Petitioner shoot the victim refutes the affidavits of Rodriguez and Viruet wherein they state',
#  '',
#  'that another person shot the victim after Petitioner fled. In addition to Wexler and',
#  '',
#  'Goncalves testimony, Charles Lopez (â\x80\x9cLopezâ\x80\x9d) testified that he was with Petitioner at the',
#  '',
#  'time of the incident and that Petitioner told him after they left the scene of the offense that',
#  '',
#  '',
#  'FALSE\tNONE\t       Wexler testified that he did not identify Petitioner as the shooter on the date of the',
#  'incident but identified him a few days later after he had seen a news report on the incident',
#  'in which Petitioner was identified as a suspect.',
#  '',
#  'FALSE\tNONE\t                                               9',
#  '',
#  'he â\x80\x9cbucked that niggerâ\x80\x9d and made three hand motions in conjunction with the statement.',
#  '',
#  'Id. at 433. Lopez stated that Petitioner told him that the victim said â\x80\x9cauâ\x80\x9d three times while',
#  '',
#  'Petitioner was shooting him. Id. at 435. Additionally, Detective Linnert testified that',
#  '',
#  'Petitioner admitted that he shot the victim in self defense three times while the victim was',
#  '',
#  'on the ground and was kicking Petitionerâ\x80\x99s legs. Finally, the evidence established that the',
#  '',
#  'bullet casings found around or in close proximity to the victim were from Petitionerâ\x80\x99s 9',
#  '',
#  'millimeter gun. For all of these reasons, the Court concludes that Petitioner has not',
#  '',
#  'established the applicability of the manifest miscarriage of justice exception to overcome',
#  '',
#  'the procedural default bar, and this claim is procedurally barred.',
#  '',
#  'FALSE\tNONE\t       Furthermore, the Court notes that a claim of actual innocence based on newly',
#  '',
#  'discovered evidence is not cognizable in habeas proceedings because federal habeas relief',
#  '',
#  'is designed to rectify constitutional violations, rather than factual errors. See Herrera v.',
#  '',
#  'Collins, 506 U.S. 390, 390-91 (1993) (â\x80\x9c[C]laims of actual innocence based on newly',
#  '',
#  'discovered evidence have never been held to state a ground for federal habeas relief absent',
#  '',
#  'an independent constitutional violation occurring in the course of the underlying state',
#  '',
#  'criminal proceedings.â\x80\x9d); Townsend v. Sain, 372 U.S. 293 (1963) (â\x80\x9c[T]he existence merely of',
#  '',
#  'newly discovered evidence relevant to the guilt of a state prisoner is not ground for relief',
#  '',
#  'on federal habeas corpus.â\x80\x9d); Jordan v. Secretary, Dept. of Corrections, 485 F.3d 1351, 1356 (11th',
#  '',
#  'Cir. 2007) (â\x80\x9cFor what it is worth, our precedent forbids granting habeas relief based upon',
#  '',
#  'a claim of actual innocence, anyway, at least in non-capital cases.â\x80\x9d); Drake v. Francis, 727',
#  '',
#  'F.2d 990, 993 (11th Cir. 1984) (â\x80\x9cIn order for a claim of newly discovered evidence to justify',
#  '',
#  '',
#  'FALSE\tNONE\t                                               10',
#  '\t\t\t\t\t\t\t\t\t\t\t   ',
#  'habeas review, the evidence must bear on the constitutionality of the defendantâ\x80\x99s',
#  '',
#  'conviction.â\x80\x9d). Petitioner did not assert in the state court that a constitutional violation',
#  '',
#  'occurred in the course of his trial. Petitioner summarily asserts in his memorandum in',
#  '',
#  'support of the instant habeas petition that his Sixth and Fourteenth Amendment rights â\x80\x9cto',
#  '',
#  'a full and fair trial and/or postconviction review was denied by the state courtâ\x80\x99s failure to',
#  '',
#  'consider the new evidence of innocence in state postconviction proceedings against the',
#  '',
#  'evidence of guilt by conducting an evidentiary hearing in the state postconviction',
#  '',
#  'proceedings.â\x80\x9d (Doc. No. 4 at 8.)      To the extent Petitioner has alleged a constitutional',
#  '',
#  'violation occurred in the state postconviction proceeding, the Court notes that â\x80\x9c[a] habeas',
#  '',
#  'petition must allege that the petitionerâ\x80\x99s detention violates the constitution, a federal',
#  '',
#  'statute, or a treaty. . . . [A] petition alleging errors in the state post-conviction review',
#  '',
#  'process is not addressable through habeas corpus proceedings.â\x80\x9d Franzen v. Brinkman, 877',
#  '',
#  'F.2d 26 (9th Cir. 1989).',
#  '',
#  'FALSE\tNONE\t       In Spradley v. Dugger, 825 F.2d 1566 (11th Cir. 1987), the petitioner argued that the',
#  '',
#  'state trial court violated his due process rights when it denied his Rule 3.850 motion',
#  '',
#  'because it did not conduct an evidentiary hearing and because its opinion denying relief',
#  '',
#  'failed to attach those portions of the record on which it relied. The Eleventh Circuit Court',
#  '',
#  'of Appeals held that the state trial courtâ\x80\x99s alleged errors in the Rule 3.850 proceedings did',
#  '',
#  'not undermine the validity of the petitionerâ\x80\x99s conviction; therefore, the claim went to issues',
#  '',
#  'unrelated to the cause of the petitionerâ\x80\x99s detention, and it did not state a basis for habeas',
#  '',
#  'relief. Id. at 1567; see also Mitchell v. Wyrick, 727 F.2d 773, 774 (8th Cir. 1984) ( â\x80\x9cEven where',
#  '',
#  '',
#  'FALSE\tNONE\t                                               11',
#  '',
#  'there may be some error in state post-conviction proceedings, this would not entitle',
#  '',
#  'appellant to federal habeas corpus relief since appellantâ\x80\x99s claim here represents an attack',
#  '',
#  'on a proceeding collateral to detention of appellant and not on the detention itself.â\x80\x9d)',
#  '',
#  '(quotation omitted) (citation omitted). Petitioner alleges error in the state post-conviction',
#  '',
#  'review process which is not addressable through the instant habeas corpus proceeding.',
#  '',
#  'Thus, even if the claim were not procedurally barred, it is not cognizable.',
#  '',
#  'FALSE\tNONE\t       Finally, even assuming that this claim was not procedurally barred and was',
#  '',
#  'cognizable, the claim would be subject to denial pursuant to Â§ 2254(d). The state trial court',
#  '',
#  'denied relief on Petitionerâ\x80\x99s claim of newly discovered evidence. (App. E at 85-88.) In so',
#  '',
#  'ruling, the state court reasoned that Rodriguezâ\x80\x99s testimony would not have made a',
#  '',
#  'difference in the outcome of the trial because:',
#  '',
#  'FALSE\tNONE\t              the medical examiner could not determine the caliber of the',
#  '              bullet that caused the victimâ\x80\x99s fatal wound to the heart, but he',
#  '              never indicated that he could determine the caliber of any',
#  '              other bullet that struck the victim. Furthermore, Rodriguez',
#  '              does not mention the caliber of the bullet or even the type of',
#  '              gun Sierra said he used. Finally, while spent casings matching',
#  '              Defendantâ\x80\x99s 9mm pistol were found near the victimâ\x80\x99s body, the',
#  '              .45 caliber casing was found in a different area. . . .',
#  '',
#  'FALSE\tNONE\t                    Furthermore, Defendant cannot establish that',
#  '              Rodriguezâ\x80\x99s hearsay testimony regarding Sierraâ\x80\x99s purported',
#  '              confession would even be admissible. . . .',
#  '',
#  'FALSE\tNONE\t                      Finally, the victim received another bullet wound that',
#  '              would have probably been fatal, i.e., a bullet pierced his right',
#  '              lung and caused internal bleeding into the chest cavity. Even',
#  '              if Defendant could offer conclusive proof that there was a',
#  '              second shooter and that he himself did not fire the fatal shot,',
#  '              he still could have been convicted of first degree murder as a',
#  '              principal. . . .',
#  '',
#  'FALSE\tNONE\t                                             12',
#  '',
#  'Id. at 86-87 (citations omitted). As to Viruetâ\x80\x99s testimony, the state court reasoned:',
#  '',
#  'FALSE\tNONE\t               [although] Viruetâ\x80\x99s testimony would presumably corroborate',
#  '               Sierraâ\x80\x99s confession . . . it would not change the fact that',
#  '               Defendant could still have been convicted of first-degree',
#  '               murder as a principal. Furthermore, there is no reasonable',
#  '               probability that it would support a self-defense theory. It',
#  '               would be inconsistent with Defendantâ\x80\x99s own statement that the',
#  '               victim was lying on his back on the pavement when Defendant',
#  '               fired three shots at him. It would also be inconsistent with the',
#  '               testimony of eyewitnesses Joseph Wexler and Bruno',
#  '               Goncalves, who asserted that Defendant walked over and shot',
#  '               the victim after others who had been fighting with him had',
#  '               caused him to end up on the ground.',
#  '',
#  'Id. at 88 (citations omitted).',
#  '',
#  'FALSE\tNONE\t       Upon review of the record, the Court concludes that Petitioner has failed to',
#  '',
#  'demonstrate by clear and convincing evidence that the state courtâ\x80\x99s determination is',
#  '',
#  'unreasonable in light of the evidence presented.            Moreover, Petitioner has not',
#  '',
#  'demonstrated that the state courtâ\x80\x99s determination is either contrary to, or an unreasonable',
#  '',
#  'application of, federal law. Accordingly, this claim is subject to denial pursuant to Â§',
#  '',
#  '2254(d).',
#  '',
#  'FALSE\tNONE\t       Any of Petitionerâ\x80\x99s allegations not specifically addressed herein have been found to',
#  '',
#  'be without merit.',
#  '',
#  'FALSE\tNONE\t       Accordingly, it is hereby ORDERED AND ADJUDGED:',
#  '',
#  '       1.      The Petition for Writ of Habeas Corpus (Doc. No. 1) filed by Fabio Nieves is',
#  '',
#  'DENIED, and this case is DISMISSED WITH PREJUDICE.',
#  '',
#  '       2.      The Clerk of the Court shall enter judgment accordingly and is directed to',
#  '',
#  'close this case.',
#  '',
#  'FALSE\tNONE\t                                             13',
#  '\t\t\t\t\t\t\t\t\t\t\t ',
#  'FALSE\tNONE\t      DONE AND ORDERED at Orlando, Florida, this 20th day of August, 2009.',
#  '',
#  '',
#  '',
#  '',
#  'Copies to:',
#  'sc 8/20',
#  'Fabio Nieves',
#  'Counsel of Record']

# %%
print(len(para))
# Out:
# 598

# %%
#select lines that contain '\t' at least ones 
para_compressed=[' ']
for line in para:
    if re.search('^.*[\\t]+.*$', line):
        para_compressed.append(line)
    else:
        if len(line)!= 0:
            para_compressed.append('\t\t' + line)

# %%
para_compressed
# Out:
# [' ',
#  '\t\tNieves v. Secretary, DOC',
#  '\t\tDescription',
#  '\t\t ORDER denying  1  Petition for writ of habeas corpus and dismissing case with prejudice; clerk is directed to enter judgment accordingly and close the case. Signed by Judge Gregory A. Presnell on 8/20/2009. (TKW)',
#  '\t\t                          UNITED STATES DISTRICT COURT',
#  '\t\t                           MIDDLE DISTRICT OF FLORIDA',
#  '\t\t                               ORLANDO DIVISION',
#  '\t\tFABIO NIEVES,',
#  '\t\t      Petitioner,',
#  '\t\tv.                                                      CASE NO. 6:08-cv-1282-Orl-31DAB',
#  '\t\tSECRETARY, DEPARTMENT OF',
#  '\t\tCORRECTIONS, et al.,',
#  '\t\t      Respondents.',
#  'TRUE\tTITLE\t                                         ORDER',
#  '\t\tPetitioner initiated this action for habeas corpus relief pursuant to 28 U.S.C. section',
#  '\t\t2254 (Doc. No. 1). Respondents filed a response to the petition in compliance with this',
#  "\t\tCourt's instructions and with the Rules Governing Section 2254 Cases in the United States",
#  '\t\tDistrict Courts (Doc. No. 9). Petitioner filed a reply and an amended reply to the response',
#  '\t\t(Doc. Nos. 12 & 14).',
#  'FALSE\tNONE\tPetitioner alleges one claim for relief in his petition, newly discovered evidence',
#  '\t\tdemonstrates his actual innocence.',
#  'TRUE\tProcedural History\t        I.    Procedural History',
#  'FALSE\tNONE\t      Petitioner was charged by indictment with one count of first degree murder. A jury',
#  '\t\ttrial was conducted in May of 1999, after which Petitioner was found guilty as charged.',
#  '\t\tThe state trial court sentenced Petitioner to a term of life imprisonment. Petitioner',
#  '\t\tappealed, and the Fifth District Court of Appeal of Florida affirmed on July 9, 1999. See',
#  '\t\tNieves v. State, 739 So. 2d 125 (Fla. 5th DCA 1999). Petitioner filed a motion for rehearing,',
#  '\t\twhich was denied on August 17, 1999. (App. A at 85.) Petitioner filed a notice to invoke',
#  '\t\tdiscretionary jurisdiction of the Supreme Court of Florida, which denied the request on',
#  '\t\tJanuary 18, 2000. Id. at 88.',
#  'FALSE\tNONE\t       Petitioner filed a Florida Rule of Criminal Procedure 3.850 motion for post-',
#  '\t\tconviction relief on January 16, 2002.1 (App. D at 14.) The state trial court summarily',
#  '\t\tdenied the motion without prejudice. Id. at 56-57. Petitioner filed a notice of supplemental',
#  '\t\tappellate record and reassertion of motion for post-conviction relief. Id. at 58-60. The state',
#  '\t\ttrial court summarily denied the Rule 3.850 motion on June 14, 2004.               Id. at 87-94.',
#  '\t\tPetitioner appealed, and the Fifth District Court of Appeal affirmed per curiam on',
#  '\t\tNovember 2, 2004. Id. at 282. Mandate was issued on November 19, 2004. Id. at 283.',
#  'FALSE\tNONE\t       On November 30, 2006, Petitioner filed a second Rule 3.850 motion, based on newly',
#  '\t\tdiscovered evidence. (App. E at 15.) The state trial court denied the motion, and Petitioner',
#  '\t\tappealed. The Fifth District Court of Appeal affirmed per curiam on May 13, 2008. Id. at',
#  '\t\t154. Mandate was issued on July 7, 2008. Id. at 160.',
#  'FALSE\tNONE\t        This is the filing date under the â\x80\x9cmailbox rule.â\x80\x9d See Thompson v. State, 761 So. 2d',
#  '\t\t324, 326 (Fla. 2000) (â\x80\x9c[W]e will presume that a legal document submitted by an inmate is',
#  '\t\ttimely filed if it contains a certificate of service showing that the pleading was placed in the',
#  '\t\thands of prison or jail officials for mailing on a particular date, if that the pleading would',
#  '\t\tbe timely filed if it had been received and file-stamped by the Court on that particular',
#  '\t\tdate.â\x80\x9d). All further references to the filing date of pleadings by Petitioner shall be the filing',
#  '\t\tdate under the mailbox rule, unless otherwise noted.',
#  'FALSE\tNONE\t                                               2',
#  'TRUE\tStandard\t        II.    Legal Standards',
#  'TRUE\tProcedural Default\t       A.     Exhaustion and Procedural Default',
#  'FALSE\tNONE\t       One procedural requirement set forth in the AEDPA precludes federal courts, absent',
#  '\t\texceptional circumstances, from granting habeas relief unless the petitioner has exhausted',
#  '\t\tall means of available relief under state law. 28 U.S.C. Â§ 2254(b); Oâ\x80\x99Sullivan v. Boerckel, 526',
#  '\t\tU.S. 838, 842-22 (1999); Picard v. Connor, 404 U.S. 270, 275 (1971). Specifically, the AEDPA',
#  '\t\tprovides, in pertinent part:',
#  'FALSE\tNONE\t       An application for a writ of habeas corpus on behalf of a person in custody',
#  '\t\t       pursuant to the judgment of a State court shall not be granted unless it',
#  '\t\t       appears thatâ\x80\x93',
#  'FALSE\tNONE\t             (A)    the applicant has exhausted the remedies available in the',
#  '\t\t                     courts of the State; or',
#  'FALSE\tNONE\t              (B)    (i)       there is an absence of available State corrective process;',
#  '\t\t                               or',
#  'FALSE\tNONE\t                     (ii)      circumstances exist that render such process ineffective',
#  '\t\t                               to protect the rights of the applicant.',
#  '\t\t28 U.S.C. Â§ 2254(b)(1).',
#  'FALSE\tNONE\t       Thus, a federal court must dismiss those claims or portions of claims that have been',
#  '\t\tdenied on adequate and independent procedural grounds under state law. Coleman v.',
#  '\t\tThompson, 501 U.S. 722, 750 (1991). In addition, a federal habeas court is precluded from',
#  '\t\tconsidering claims that are not exhausted but would clearly be barred if returned to state',
#  '\t\tcourt. Id. at 735 n.1 (stating that if the petitioner failed to exhaust state remedies and the',
#  '\t\tcourt to which the petitioner would be required to present his claims in order to meet the',
#  '\t\texhaustion requirement would now find the claims procedurally barred, there is a',
#  'FALSE\tNONE\t                                                3',
#  '\t\tprocedural default for federal habeas purposes regardless of the decision of the last state',
#  '\t\tcourt to which the petitioner actually presented his claims).',
#  'FALSE\tNONE\t       In order to satisfy the exhaustion requirement, a state petitioner must â\x80\x9cfairly',
#  '\t\tpresen[t] federal claims to the state courts in order to give the State the opportunity to pass',
#  '\t\tupon and correct alleged violations of its prisonersâ\x80\x99 federal rights.â\x80\x9d Duncan v. Henry, 513',
#  '\t\tU.S. 364, 365 (1995) (citing Picard, 404 U.S. at 275-76) (internal quotation marks omitted).',
#  '\t\tThe petitioner must apprise the state court of the federal constitutional issue, not just the',
#  '\t\tunderlying facts of the claim or a similar state law claim. Snowden v. Singletary, 135 F.3d',
#  '\t\t732 (11th Cir. 1998). The United States Supreme Court has observed that â\x80\x9cCongress surely',
#  '\t\tmeant that exhaustion be serious and meaningful.â\x80\x9d Keeney v. Tamayo-Reyes, 504 U.S. 1, 10',
#  '\t\t(1992). Furthermore, the Court explained:',
#  'FALSE\tNONE\t       [c]omity concerns dictate that the requirement of exhaustion is not satisfied',
#  '\t\t       by the mere statement of a federal claim in state court. Just as the State must',
#  '\t\t       afford the petitioner a full and fair hearing on his federal claim, so must the',
#  '\t\t       petitioner afford the State a full and fair opportunity to address and resolve',
#  '\t\t       the claims on the merits.',
#  '\t\tId.; see also Henderson v. Campbell, 353 F.3d 880, 898 n.25 (11th Cir. 2003) (â\x80\x9cBoth the legal',
#  '\t\ttheory and the facts on which the federal claim rests must be substantially the same for it',
#  '\t\tto be the substantial equivalent of the properly exhausted claim.â\x80\x9d).',
#  'FALSE\tNONE\t       Procedural default will be excused only in two narrow circumstances. First, a',
#  '\t\tpetitioner may obtain federal review of a procedurally defaulted claim if he can show both',
#  '\t\tâ\x80\x9ccauseâ\x80\x9d for the default and actual â\x80\x9cprejudiceâ\x80\x9d resulting from the default. â\x80\x9cTo establish',
#  '\t\tâ\x80\x98causeâ\x80\x99 for procedural default, a petitioner must demonstrate that some objective factor',
#  'FALSE\tNONE\t                                             4',
#  '\t\texternal to the defense impeded the effort to raise the claim properly in the state court.â\x80\x9d',
#  '\t\tWright v. Hopper, 169 F.3d 695, 703 (11th Cir. 1999). To establish â\x80\x9cprejudice,â\x80\x9d a petitioner',
#  '\t\tmust show that there is at least a reasonable probability that the result of the proceeding',
#  '\t\twould have been different. Henderson, 353 F.3d at 892 (citations omitted).',
#  'FALSE\tNONE\t       The second exception, known as the â\x80\x9cfundamental miscarriage of justice,â\x80\x9d only',
#  '\t\toccurs in an extraordinary case, where a â\x80\x9cconstitutional violation has probably resulted in',
#  '\t\tthe conviction of one who is actually innocent.â\x80\x9d Murray v. Carrier, 477 U.S. 478, 496 (1986).',
#  '\t\tActual innocence means factual innocence, not legal insufficiency. Bousley v. United States,',
#  '\t\t523 U.S. 614, 623 (1998). To meet this standard, a petitioner must â\x80\x9cshow that it is more',
#  '\t\tlikely than not that no reasonable juror would have convicted himâ\x80\x9d of the underlying',
#  '\t\toffense. Schlup v. Delo, 513 U.S. 298, 327 (1995). In addition, â\x80\x9câ\x80\x98[t]o be credible,â\x80\x99 a claim of',
#  '\t\tactual innocence must be based on [new] reliable evidence not presented at trial.â\x80\x9d Calderon',
#  '\t\tv. Thompson, 523 U.S. 538, 559 (1998) (quoting Schlup, 513 U.S. at 324).',
#  'TRUE\tStandard of Review\t       B.     Standard of Review Under the Antiterrorism Effective Death Penalty Act',
#  '\t\t              (â\x80\x9cAEDPAâ\x80\x9d)',
#  'FALSE\tNONE\t       Pursuant to the AEDPA, federal habeas relief may not be granted with respect to a',
#  '\t\tclaim adjudicated on the merits in state court unless the adjudication of the claim:',
#  'FALSE\tNONE\t       (1)    resulted in a decision that was contrary to, or involved an',
#  '\t\t              unreasonable application of, clearly established Federal law, as',
#  '\t\t              determined by the Supreme Court of the United States; or',
#  'FALSE\tNONE\t       (2)    resulted in a decision that was based on an unreasonable',
#  '\t\t              determination of the facts in light of the evidence presented in the',
#  '\t\t              State court proceeding.',
#  'FALSE\tNONE\t                                              5',
#  '\t\t28 U.S.C. Â§ 2254(d). The phrase â\x80\x9cclearly established Federal law,â\x80\x9d encompasses only the',
#  '\t\tholdings of the United States Supreme Court â\x80\x9cas of the time of the relevant state-court',
#  '\t\tdecision.â\x80\x9d Williams v. Taylor, 529 U.S. 362, 412 (2000).',
#  'FALSE\tNONE\t       â\x80\x9c[S]ection 2254(d)(1) provides two separate bases for reviewing state court decisions;',
#  '\t\tthe â\x80\x98contrary toâ\x80\x99 and â\x80\x98unreasonable applicationâ\x80\x99 clauses articulate independent',
#  '\t\tconsiderations a federal court must consider.â\x80\x9d Maharaj v. Secretary for Depâ\x80\x99t. of Corr., 432',
#  '\t\tF.3d 1292, 1308 (11th Cir. 2005). The meaning of the clauses was discussed by the Eleventh',
#  '\t\tCircuit Court of Appeals in Parker v. Head, 244 F.3d 831, 835 (11th Cir. 2001):',
#  'FALSE\tNONE\t       Under the â\x80\x9ccontrary toâ\x80\x9d clause, a federal court may grant the writ if the state',
#  '\t\t       court arrives at a conclusion opposite to that reached by [the United States',
#  '\t\t       Supreme Court] on a question of law or if the state court decides a case',
#  '\t\t       differently than [the United States Supreme Court] has on a set of materially',
#  '\t\t       indistinguishable facts. Under the â\x80\x98unreasonable applicationâ\x80\x99 clause, a',
#  '\t\t       federal habeas court may grant the writ if the state court identifies the correct',
#  '\t\t       governing legal principle from [the United States Supreme Courtâ\x80\x99s] decisions',
#  "\t\t       but unreasonably applies that principle to the facts of the prisoner's case.",
#  '\t\tEven if the federal court concludes that the state court applied federal law incorrectly,',
#  '\t\thabeas relief is appropriate only if that application was â\x80\x9cobjectively unreasonable.â\x80\x9d2 Id.',
#  'FALSE\tNONE\t       Finally, under Â§ 2254(d)(2), a federal court may grant a writ of habeas corpus if the',
#  '\t\tstate courtâ\x80\x99s decision â\x80\x9cwas based on an unreasonable determination of the facts in light of',
#  'FALSE\tNONE\t        In considering the â\x80\x9cunreasonable applicationâ\x80\x9dinquiry, the Court must determine',
#  "\t\tâ\x80\x9cwhether the state court's application of clearly established federal law was objectively",
#  "\t\tunreasonable.â\x80\x9d Williams, 529 U.S. at 409. Whether a state court's decision was an",
#  '\t\tunreasonable application of law must be assessed in light of the record before the state',
#  '\t\tcourt. Holland v. Jackson, 542 U.S. 649, 652 (2004) (per curiam); cf. Bell v. Cone, 535 U.S. 685,',
#  '\t\t697 n. 4 (2002) (declining to consider evidence not presented to state court in determining',
#  '\t\twhether its decision was contrary to federal law).',
#  'FALSE\tNONE\t                                               6',
#  '\t\tthe evidence presented in the State court proceeding.â\x80\x9d A determination of a factual issue',
#  '\t\tmade by a state court, however, shall be presumed correct, and the habeas petitioner shall',
#  '\t\thave the burden of rebutting the presumption of correctness by clear and convincing',
#  '\t\tevidence. See Parker, 244 F.3d at 835-36; 28 U.S.C. Â§ 2254(e)(1).',
#  'TRUE\tAnalysis\t        III.   Analysis',
#  'FALSE\tNONE\t       Petitioner asserts that newly discovered evidence exculpates him of first degree',
#  '\t\tmurder.    In support of his claim, Petitioner relies on the affidavits of Joel Rodriguez',
#  '\t\t(â\x80\x9cRodriguezâ\x80\x9d) and Waldemar Viruet (â\x80\x9cViruetâ\x80\x9d), prison inmates. Specifically, Rodriguez',
#  '\t\tattested on December 14, 2005, that while he was incarcerated at the Orange County Jail',
#  '\t\tbetween July and September of 1998, Joel Sierra (â\x80\x9cSierraâ\x80\x9d) told him that (1) he saw',
#  '\t\tPetitioner running away from the victim who was lying on the ground, (2) he saw the',
#  '\t\tvictim try to get up, and (3) he (Sierra) shot the victim because he thought the victim might',
#  '\t\tshoot Petitioner and the victim appeared to be suffering. See Doc. No. 1 at 23-25. According',
#  '\t\tto Rodriguez, Sierra said that he knew Petitioner had been convicted for the murder. Id.',
#  '\t\tat 25. Viruet attested on December 17, 2006, that he observed the events surrounding the',
#  '\t\tmurder from across the street from the McDonaldâ\x80\x99s where the offense occurred. Id. at 27-',
#  '\t\t28. According to Viruet, he recognized Petitioner as one of the guys involved in the fight,',
#  '\t\tand although he could not hear what was said, Viruet saw the victim attack Petitioner, and',
#  '\t\tas they started to fall to the ground, the gun went off. Id. at 27. Viruet attested that he saw',
#  '\t\tPetitioner get to his feet and run away after which he observed another man approach the',
#  '\t\tvictim, who was rolling around on the ground, and shoot the victim. Id. at 28.',
#  'FALSE\tNONE\t                                              7',
#  'FALSE\tNONE\t       Respondents assert that Petitionerâ\x80\x99s claim is procedurally barred from review',
#  '\t\tbecause it was not raised as a federal claim in the state courts. The record demonstrates',
#  '\t\tthat the instant claim was not raised as a federal constitutional claim in the state courts.',
#  '\t\tPetitioner cited only to state cases in support of his claim, and all of his substantive',
#  '\t\targuments addressed Florida law. Nothing in the claim, therefore, would have alerted the',
#  '\t\tstate court to the presence of a federal claim. Thus, this claim was not exhausted and is',
#  '\t\tprocedurally barred absent application of one of the exceptions.',
#  'FALSE\tNONE\t       In the present case, Petitioner has not shown either cause or prejudice that would',
#  '\t\texcuse the default. Likewise, Petitioner has not shown the applicability of the fundamental',
#  '\t\tmiscarriage of justice exception. To the extent Petitioner relies on the affidavits of',
#  '\t\tRodriguez and Viruet to establish the application of the fundamental miscarriage of justice',
#  '\t\texception, the Court concludes that this evidence is not reliable and Petitioner has not',
#  '\t\tdemonstrated that it is more likely than not that no reasonable juror would have convicted',
#  '\t\thim given this evidence.',
#  'FALSE\tNONE\t       First, both Rodriguez and Viruet, who are inmates, provided Petitioner with',
#  '\t\tstatements more than six years after Petitionerâ\x80\x99s trial. Neither of them notified law',
#  '\t\tenforcement at any point of what they saw on the night of the incident or heard regarding',
#  '\t\tthe incident. Moreover, the statements contained in Rodriguezâ\x80\x99s affidavit that Sierra',
#  '\t\tadmitted shooting the victim after Petitioner fled are hearsay statements. For these',
#  '\t\treasons, the Court cannot find that Petitionerâ\x80\x99s newly discovered evidence is reliable.',
#  'FALSE\tNONE\t                                             8',
#  'FALSE\tNONE\t       Moreover, even assuming that the newly discovered evidence were reliable, the',
#  '\t\tevidence presented at trial refutes the application of the actual innocence exception. At',
#  '\t\ttrial, Todd Wexler (â\x80\x9cWexlerâ\x80\x9d) testified that he saw Petitioner shoot the victim four times',
#  '\t\tin rapid succession.3 (App. B at 339, 360, 365.) Wexler further testified that after Petitioner',
#  '\t\tshot the victim and Petitioner and the others who were near the victim ran away, Wexler',
#  '\t\timmediately walked to the victim. Id. at 340, 359. Wexler stated that he heard two shots',
#  '\t\tprior to Petitioner shooting the victim, but Wexler did not indicate that he heard or saw',
#  '\t\tany shots fired after he saw Petitioner shoot the victim. Id. at 385, 387.',
#  'FALSE\tNONE\t       Bruno Goncalves (â\x80\x9cGoncalvesâ\x80\x9d) also testified that he saw Petitioner shoot the victim',
#  '\t\tfour times in rapid succession. (App. B at 393, 402, 410-11.) Like Wexler, Goncalves',
#  '\t\ttestified that he (Goncalves) went to the victim immediately after the victim was shot. Id.',
#  '\t\tat 394. Goncalves testified that he heard one gunshot in the McDonaldâ\x80\x99s parking lot prior',
#  '\t\tto the victim being shot, but Goncalves did not indicate that he saw or heard any shots',
#  '\t\tfired after Petitioner shot the victim. Id. at 401.',
#  'FALSE\tNONE\t       Wexler and Goncalvesâ\x80\x99 testimony that they went to the victim after they saw',
#  '\t\tPetitioner shoot the victim refutes the affidavits of Rodriguez and Viruet wherein they state',
#  '\t\tthat another person shot the victim after Petitioner fled. In addition to Wexler and',
#  '\t\tGoncalves testimony, Charles Lopez (â\x80\x9cLopezâ\x80\x9d) testified that he was with Petitioner at the',
#  '\t\ttime of the incident and that Petitioner told him after they left the scene of the offense that',
#  'FALSE\tNONE\t       Wexler testified that he did not identify Petitioner as the shooter on the date of the',
#  '\t\tincident but identified him a few days later after he had seen a news report on the incident',
#  '\t\tin which Petitioner was identified as a suspect.',
#  'FALSE\tNONE\t                                               9',
#  '\t\the â\x80\x9cbucked that niggerâ\x80\x9d and made three hand motions in conjunction with the statement.',
#  '\t\tId. at 433. Lopez stated that Petitioner told him that the victim said â\x80\x9cauâ\x80\x9d three times while',
#  '\t\tPetitioner was shooting him. Id. at 435. Additionally, Detective Linnert testified that',
#  '\t\tPetitioner admitted that he shot the victim in self defense three times while the victim was',
#  '\t\ton the ground and was kicking Petitionerâ\x80\x99s legs. Finally, the evidence established that the',
#  '\t\tbullet casings found around or in close proximity to the victim were from Petitionerâ\x80\x99s 9',
#  '\t\tmillimeter gun. For all of these reasons, the Court concludes that Petitioner has not',
#  '\t\testablished the applicability of the manifest miscarriage of justice exception to overcome',
#  '\t\tthe procedural default bar, and this claim is procedurally barred.',
#  'FALSE\tNONE\t       Furthermore, the Court notes that a claim of actual innocence based on newly',
#  '\t\tdiscovered evidence is not cognizable in habeas proceedings because federal habeas relief',
#  '\t\tis designed to rectify constitutional violations, rather than factual errors. See Herrera v.',
#  '\t\tCollins, 506 U.S. 390, 390-91 (1993) (â\x80\x9c[C]laims of actual innocence based on newly',
#  '\t\tdiscovered evidence have never been held to state a ground for federal habeas relief absent',
#  '\t\tan independent constitutional violation occurring in the course of the underlying state',
#  '\t\tcriminal proceedings.â\x80\x9d); Townsend v. Sain, 372 U.S. 293 (1963) (â\x80\x9c[T]he existence merely of',
#  '\t\tnewly discovered evidence relevant to the guilt of a state prisoner is not ground for relief',
#  '\t\ton federal habeas corpus.â\x80\x9d); Jordan v. Secretary, Dept. of Corrections, 485 F.3d 1351, 1356 (11th',
#  '\t\tCir. 2007) (â\x80\x9cFor what it is worth, our precedent forbids granting habeas relief based upon',
#  '\t\ta claim of actual innocence, anyway, at least in non-capital cases.â\x80\x9d); Drake v. Francis, 727',
#  '\t\tF.2d 990, 993 (11th Cir. 1984) (â\x80\x9cIn order for a claim of newly discovered evidence to justify',
#  'FALSE\tNONE\t                                               10',
#  '\t\t\t\t\t\t\t\t\t\t\t   ',
#  '\t\thabeas review, the evidence must bear on the constitutionality of the defendantâ\x80\x99s',
#  '\t\tconviction.â\x80\x9d). Petitioner did not assert in the state court that a constitutional violation',
#  '\t\toccurred in the course of his trial. Petitioner summarily asserts in his memorandum in',
#  '\t\tsupport of the instant habeas petition that his Sixth and Fourteenth Amendment rights â\x80\x9cto',
#  '\t\ta full and fair trial and/or postconviction review was denied by the state courtâ\x80\x99s failure to',
#  '\t\tconsider the new evidence of innocence in state postconviction proceedings against the',
#  '\t\tevidence of guilt by conducting an evidentiary hearing in the state postconviction',
#  '\t\tproceedings.â\x80\x9d (Doc. No. 4 at 8.)      To the extent Petitioner has alleged a constitutional',
#  '\t\tviolation occurred in the state postconviction proceeding, the Court notes that â\x80\x9c[a] habeas',
#  '\t\tpetition must allege that the petitionerâ\x80\x99s detention violates the constitution, a federal',
#  '\t\tstatute, or a treaty. . . . [A] petition alleging errors in the state post-conviction review',
#  '\t\tprocess is not addressable through habeas corpus proceedings.â\x80\x9d Franzen v. Brinkman, 877',
#  '\t\tF.2d 26 (9th Cir. 1989).',
#  'FALSE\tNONE\t       In Spradley v. Dugger, 825 F.2d 1566 (11th Cir. 1987), the petitioner argued that the',
#  '\t\tstate trial court violated his due process rights when it denied his Rule 3.850 motion',
#  '\t\tbecause it did not conduct an evidentiary hearing and because its opinion denying relief',
#  '\t\tfailed to attach those portions of the record on which it relied. The Eleventh Circuit Court',
#  '\t\tof Appeals held that the state trial courtâ\x80\x99s alleged errors in the Rule 3.850 proceedings did',
#  '\t\tnot undermine the validity of the petitionerâ\x80\x99s conviction; therefore, the claim went to issues',
#  '\t\tunrelated to the cause of the petitionerâ\x80\x99s detention, and it did not state a basis for habeas',
#  '\t\trelief. Id. at 1567; see also Mitchell v. Wyrick, 727 F.2d 773, 774 (8th Cir. 1984) ( â\x80\x9cEven where',
#  'FALSE\tNONE\t                                               11',
#  '\t\tthere may be some error in state post-conviction proceedings, this would not entitle',
#  '\t\tappellant to federal habeas corpus relief since appellantâ\x80\x99s claim here represents an attack',
#  '\t\ton a proceeding collateral to detention of appellant and not on the detention itself.â\x80\x9d)',
#  '\t\t(quotation omitted) (citation omitted). Petitioner alleges error in the state post-conviction',
#  '\t\treview process which is not addressable through the instant habeas corpus proceeding.',
#  '\t\tThus, even if the claim were not procedurally barred, it is not cognizable.',
#  'FALSE\tNONE\t       Finally, even assuming that this claim was not procedurally barred and was',
#  '\t\tcognizable, the claim would be subject to denial pursuant to Â§ 2254(d). The state trial court',
#  '\t\tdenied relief on Petitionerâ\x80\x99s claim of newly discovered evidence. (App. E at 85-88.) In so',
#  '\t\truling, the state court reasoned that Rodriguezâ\x80\x99s testimony would not have made a',
#  '\t\tdifference in the outcome of the trial because:',
#  'FALSE\tNONE\t              the medical examiner could not determine the caliber of the',
#  '\t\t              bullet that caused the victimâ\x80\x99s fatal wound to the heart, but he',
#  '\t\t              never indicated that he could determine the caliber of any',
#  '\t\t              other bullet that struck the victim. Furthermore, Rodriguez',
#  '\t\t              does not mention the caliber of the bullet or even the type of',
#  '\t\t              gun Sierra said he used. Finally, while spent casings matching',
#  '\t\t              Defendantâ\x80\x99s 9mm pistol were found near the victimâ\x80\x99s body, the',
#  '\t\t              .45 caliber casing was found in a different area. . . .',
#  'FALSE\tNONE\t                    Furthermore, Defendant cannot establish that',
#  '\t\t              Rodriguezâ\x80\x99s hearsay testimony regarding Sierraâ\x80\x99s purported',
#  '\t\t              confession would even be admissible. . . .',
#  'FALSE\tNONE\t                      Finally, the victim received another bullet wound that',
#  '\t\t              would have probably been fatal, i.e., a bullet pierced his right',
#  '\t\t              lung and caused internal bleeding into the chest cavity. Even',
#  '\t\t              if Defendant could offer conclusive proof that there was a',
#  '\t\t              second shooter and that he himself did not fire the fatal shot,',
#  '\t\t              he still could have been convicted of first degree murder as a',
#  '\t\t              principal. . . .',
#  'FALSE\tNONE\t                                             12',
#  '\t\tId. at 86-87 (citations omitted). As to Viruetâ\x80\x99s testimony, the state court reasoned:',
#  'FALSE\tNONE\t               [although] Viruetâ\x80\x99s testimony would presumably corroborate',
#  '\t\t               Sierraâ\x80\x99s confession . . . it would not change the fact that',
#  '\t\t               Defendant could still have been convicted of first-degree',
#  '\t\t               murder as a principal. Furthermore, there is no reasonable',
#  '\t\t               probability that it would support a self-defense theory. It',
#  '\t\t               would be inconsistent with Defendantâ\x80\x99s own statement that the',
#  '\t\t               victim was lying on his back on the pavement when Defendant',
#  '\t\t               fired three shots at him. It would also be inconsistent with the',
#  '\t\t               testimony of eyewitnesses Joseph Wexler and Bruno',
#  '\t\t               Goncalves, who asserted that Defendant walked over and shot',
#  '\t\t               the victim after others who had been fighting with him had',
#  '\t\t               caused him to end up on the ground.',
#  '\t\tId. at 88 (citations omitted).',
#  'FALSE\tNONE\t       Upon review of the record, the Court concludes that Petitioner has failed to',
#  '\t\tdemonstrate by clear and convincing evidence that the state courtâ\x80\x99s determination is',
#  '\t\tunreasonable in light of the evidence presented.            Moreover, Petitioner has not',
#  '\t\tdemonstrated that the state courtâ\x80\x99s determination is either contrary to, or an unreasonable',
#  '\t\tapplication of, federal law. Accordingly, this claim is subject to denial pursuant to Â§',
#  '\t\t2254(d).',
#  'FALSE\tNONE\t       Any of Petitionerâ\x80\x99s allegations not specifically addressed herein have been found to',
#  '\t\tbe without merit.',
#  'FALSE\tNONE\t       Accordingly, it is hereby ORDERED AND ADJUDGED:',
#  '\t\t       1.      The Petition for Writ of Habeas Corpus (Doc. No. 1) filed by Fabio Nieves is',
#  '\t\tDENIED, and this case is DISMISSED WITH PREJUDICE.',
#  '\t\t       2.      The Clerk of the Court shall enter judgment accordingly and is directed to',
#  '\t\tclose this case.',
#  'FALSE\tNONE\t                                             13',
#  '\t\t\t\t\t\t\t\t\t\t\t ',
#  'FALSE\tNONE\t      DONE AND ORDERED at Orlando, Florida, this 20th day of August, 2009.',
#  '\t\tCopies to:',
#  '\t\tsc 8/20',
#  '\t\tFabio Nieves',
#  '\t\tCounsel of Record']

# %%
data='\n'.join(para_compressed)

# %%
# for no,line in enumerate(para):
#     print(no,line)

# %%
import pandas as pd
from io import StringIO
import numpy as np

# %%
TESTDATA = StringIO(data)

# %%
parser=pd.read_csv(TESTDATA,sep='\t',names=['is_header','section_type','section'])

# %%
parser
# Out:
#     is_header        section_type  \
# 0         NaN                 NaN
# 1         NaN                 NaN
# 2         NaN                 NaN
# 3         NaN                 NaN
# 4         NaN                 NaN
# 5         NaN                 NaN
# 6         NaN                 NaN
# 7         NaN                 NaN
# 8         NaN                 NaN
# 9         NaN                 NaN
# 10        NaN                 NaN
# 11        NaN                 NaN
# 12       True               TITLE
# 13        NaN                 NaN
# 14        NaN                 NaN
# 15        NaN                 NaN
# 16        NaN                 NaN
# 17        NaN                 NaN
# 18      False                NONE
# 19        NaN                 NaN
# 20       True  Procedural History
# 21      False                NONE
# 22        NaN                 NaN
# 23        NaN                 NaN
# 24        NaN                 NaN
# 25        NaN                 NaN
# 26        NaN                 NaN
# 27        NaN                 NaN
# 28        NaN                 NaN
# 29      False                NONE
# ..        ...                 ...
# 294       NaN                 NaN
# 295       NaN                 NaN
# 296       NaN                 NaN
# 297       NaN                 NaN
# 298       NaN                 NaN
# 299       NaN                 NaN
# 300       NaN                 NaN
# 301       NaN                 NaN
# 302       NaN                 NaN
# 303       NaN                 NaN
# 304     False                NONE
# 305       NaN                 NaN
# 306       NaN                 NaN
# 307       NaN                 NaN
# 308       NaN                 NaN
# 309       NaN                 NaN
# 310     False                NONE
# 311       NaN                 NaN
# 312     False                NONE
# 313       NaN                 NaN
# 314       NaN                 NaN
# 315       NaN                 NaN
# 316       NaN                 NaN
# 317     False                NONE
# 318       NaN                 NaN
# 319     False                NONE
# 320       NaN                 NaN
# 321       NaN                 NaN
# 322       NaN                 NaN
# 323       NaN                 NaN
#
#                                                section
# 0                             Nieves v. Secretary, DOC
# 1                                          Description
# 2     ORDER denying  1  Petition for writ of habeas...
# 3                              UNITED STATES DISTRI...
# 4                               MIDDLE DISTRICT OF ...
# 5                                     ORLANDO DIVISION
# 6                                        FABIO NIEVES,
# 7                                          Petitioner,
# 8    v.                                            ...
# 9                             SECRETARY, DEPARTMENT OF
# 10                                CORRECTIONS, et al.,
# 11                                        Respondents.
# 12                                               ORDER
# 13   Petitioner initiated this action for habeas co...
# 14   2254 (Doc. No. 1). Respondents filed a respons...
# 15   Court's instructions and with the Rules Govern...
# 16   District Courts (Doc. No. 9). Petitioner filed...
# 17                                (Doc. Nos. 12 & 14).
# 18   Petitioner alleges one claim for relief in his...
# 19                  demonstrates his actual innocence.
# 20                            I.    Procedural History
# 21         Petitioner was charged by indictment wit...
# 22   trial was conducted in May of 1999, after whic...
# 23   The state trial court sentenced Petitioner to ...
# 24   appealed, and the Fifth District Court of Appe...
# 25   Nieves v. State, 739 So. 2d 125 (Fla. 5th DCA ...
# 26   which was denied on August 17, 1999. (App. A a...
# 27   discretionary jurisdiction of the Supreme Cour...
# 28                        January 18, 2000. Id. at 88.
# 29          Petitioner filed a Florida Rule of Crim...
# ..                                                 ...
# 294                 murder as a principal. Furtherm...
# 295                 probability that it would suppo...
# 296                 would be inconsistent with Defe...
# 297                 victim was lying on his back on...
# 298                 fired three shots at him. It wo...
# 299                 testimony of eyewitnesses Josep...
# 300                 Goncalves, who asserted that De...
# 301                 the victim after others who had...
# 302                 caused him to end up on the gro...
# 303                     Id. at 88 (citations omitted).
# 304         Upon review of the record, the Court co...
# 305  demonstrate by clear and convincing evidence t...
# 306  unreasonable in light of the evidence presente...
# 307  demonstrated that the state courtâs determin...
# 308  application of, federal law. Accordingly, this...
# 309                                           2254(d).
# 310         Any of Petitionerâs allegations not s...
# 311                                  be without merit.
# 312         Accordingly, it is hereby ORDERED AND A...
# 313         1.      The Petition for Writ of Habeas...
# 314  DENIED, and this case is DISMISSED WITH PREJUD...
# 315         2.      The Clerk of the Court shall en...
# 316                                   close this case.
# 317                                                 13
# 318                                                NaN
# 319        DONE AND ORDERED at Orlando, Florida, th...
# 320                                         Copies to:
# 321                                            sc 8/20
# 322                                       Fabio Nieves
# 323                                  Counsel of Record
#
# [324 rows x 3 columns]

# %%
#remove NaN rows
# ind = parser['section'].index[parser['section'].apply(pd.isnull)]
# ind = list(reversed(ind))#reverse the list (eviter decalage )
# for i in ind:
#     print(parser.index[i])
#     parser = parser.drop(parser.index[i])
parser['is_header'] = parser['is_header'].fillna(False)
parser['section_type'] = parser['section_type'].fillna('None')
parser=parser.dropna()

# %%
parser
# Out:
#      is_header        section_type  \
# 0        False                None
# 1        False                None
# 2        False                None
# 3        False                None
# 4        False                None
# 5        False                None
# 6        False                None
# 7        False                None
# 8        False                None
# 9        False                None
# 10       False                None
# 11       False                None
# 12        True               TITLE
# 13       False                None
# 14       False                None
# 15       False                None
# 16       False                None
# 17       False                None
# 18       False                NONE
# 19       False                None
# 20        True  Procedural History
# 21       False                NONE
# 22       False                None
# 23       False                None
# 24       False                None
# 25       False                None
# 26       False                None
# 27       False                None
# 28       False                None
# 29       False                NONE
# ..         ...                 ...
# 293      False                None
# 294      False                None
# 295      False                None
# 296      False                None
# 297      False                None
# 298      False                None
# 299      False                None
# 300      False                None
# 301      False                None
# 302      False                None
# 303      False                None
# 304      False                NONE
# 305      False                None
# 306      False                None
# 307      False                None
# 308      False                None
# 309      False                None
# 310      False                NONE
# 311      False                None
# 312      False                NONE
# 313      False                None
# 314      False                None
# 315      False                None
# 316      False                None
# 317      False                NONE
# 319      False                NONE
# 320      False                None
# 321      False                None
# 322      False                None
# 323      False                None
#
#                                                section
# 0                             Nieves v. Secretary, DOC
# 1                                          Description
# 2     ORDER denying  1  Petition for writ of habeas...
# 3                              UNITED STATES DISTRI...
# 4                               MIDDLE DISTRICT OF ...
# 5                                     ORLANDO DIVISION
# 6                                        FABIO NIEVES,
# 7                                          Petitioner,
# 8    v.                                            ...
# 9                             SECRETARY, DEPARTMENT OF
# 10                                CORRECTIONS, et al.,
# 11                                        Respondents.
# 12                                               ORDER
# 13   Petitioner initiated this action for habeas co...
# 14   2254 (Doc. No. 1). Respondents filed a respons...
# 15   Court's instructions and with the Rules Govern...
# 16   District Courts (Doc. No. 9). Petitioner filed...
# 17                                (Doc. Nos. 12 & 14).
# 18   Petitioner alleges one claim for relief in his...
# 19                  demonstrates his actual innocence.
# 20                            I.    Procedural History
# 21         Petitioner was charged by indictment wit...
# 22   trial was conducted in May of 1999, after whic...
# 23   The state trial court sentenced Petitioner to ...
# 24   appealed, and the Fifth District Court of Appe...
# 25   Nieves v. State, 739 So. 2d 125 (Fla. 5th DCA ...
# 26   which was denied on August 17, 1999. (App. A a...
# 27   discretionary jurisdiction of the Supreme Cour...
# 28                        January 18, 2000. Id. at 88.
# 29          Petitioner filed a Florida Rule of Crim...
# ..                                                 ...
# 293                 Defendant could still have been...
# 294                 murder as a principal. Furtherm...
# 295                 probability that it would suppo...
# 296                 would be inconsistent with Defe...
# 297                 victim was lying on his back on...
# 298                 fired three shots at him. It wo...
# 299                 testimony of eyewitnesses Josep...
# 300                 Goncalves, who asserted that De...
# 301                 the victim after others who had...
# 302                 caused him to end up on the gro...
# 303                     Id. at 88 (citations omitted).
# 304         Upon review of the record, the Court co...
# 305  demonstrate by clear and convincing evidence t...
# 306  unreasonable in light of the evidence presente...
# 307  demonstrated that the state courtâs determin...
# 308  application of, federal law. Accordingly, this...
# 309                                           2254(d).
# 310         Any of Petitionerâs allegations not s...
# 311                                  be without merit.
# 312         Accordingly, it is hereby ORDERED AND A...
# 313         1.      The Petition for Writ of Habeas...
# 314  DENIED, and this case is DISMISSED WITH PREJUD...
# 315         2.      The Clerk of the Court shall en...
# 316                                   close this case.
# 317                                                 13
# 319        DONE AND ORDERED at Orlando, Florida, th...
# 320                                         Copies to:
# 321                                            sc 8/20
# 322                                       Fabio Nieves
# 323                                  Counsel of Record
#
# [322 rows x 3 columns]

# %%
# for p in soup.find_all('p'):
#     for a in soup.find_all('a'):
    
#     print(p.next_sibling)
#     type(soup)
#     soup.find_all('br')

# %%
# moby = nltk.Text(files.words('test.html'))
# moby.findall(r" <p> (.*?) </p>") 
# re.findall(r'^|w+', 'two words')
# text = "He was carefully disguised but captured quickly by police."
# re.findall(r"\w+ly", text)

# %%
parser.head()
# Out:
#    is_header section_type                                            section
# 0      False         None                           Nieves v. Secretary, DOC
# 1      False         None                                        Description
# 2      False         None   ORDER denying  1  Petition for writ of habeas...
# 3      False         None                            UNITED STATES DISTRI...
# 4      False         None                             MIDDLE DISTRICT OF ...

# %%
parser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 322 entries, 0 to 323
# Data columns (total 3 columns):
# is_header       322 non-null bool
# section_type    322 non-null object
# section         322 non-null object
# dtypes: bool(1), object(2)
# memory usage: 7.9+ KB

# %%
parser.describe()
# Out:
#        is_header section_type  \
# count        322          322
# unique         2            8
# top        False         None
# freq         316          263
#
#                                                   section
# count                                                 322
# unique                                                322
# top            B.     Standard of Review Under the Ant...
# freq                                                    1

# %%
#remove spaces in begening and end of sections
parser['section'] = parser['section'].map(lambda x: x.lstrip(' ').rstrip(' '))
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
parser['stringLength'] = parser['section'].apply(len)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#remove page's numbers
# for l in parser['stringLength']:
#     if l<4:
#          parser = parser.drop(l)
parser = parser.drop(parser[parser['stringLength']<4].index)

# %%
parser
# Out:
#      is_header        section_type  \
# 0        False                None
# 1        False                None
# 2        False                None
# 3        False                None
# 4        False                None
# 5        False                None
# 6        False                None
# 7        False                None
# 8        False                None
# 9        False                None
# 10       False                None
# 11       False                None
# 12        True               TITLE
# 13       False                None
# 14       False                None
# 15       False                None
# 16       False                None
# 17       False                None
# 18       False                NONE
# 19       False                None
# 20        True  Procedural History
# 21       False                NONE
# 22       False                None
# 23       False                None
# 24       False                None
# 25       False                None
# 26       False                None
# 27       False                None
# 28       False                None
# 29       False                NONE
# ..         ...                 ...
# 292      False                None
# 293      False                None
# 294      False                None
# 295      False                None
# 296      False                None
# 297      False                None
# 298      False                None
# 299      False                None
# 300      False                None
# 301      False                None
# 302      False                None
# 303      False                None
# 304      False                NONE
# 305      False                None
# 306      False                None
# 307      False                None
# 308      False                None
# 309      False                None
# 310      False                NONE
# 311      False                None
# 312      False                NONE
# 313      False                None
# 314      False                None
# 315      False                None
# 316      False                None
# 319      False                NONE
# 320      False                None
# 321      False                None
# 322      False                None
# 323      False                None
#
#                                                section  stringLength
# 0                             Nieves v. Secretary, DOC            24
# 1                                          Description            11
# 2    ORDER denying  1  Petition for writ of habeas ...           212
# 3                         UNITED STATES DISTRICT COURT            28
# 4                           MIDDLE DISTRICT OF FLORIDA            26
# 5                                     ORLANDO DIVISION            16
# 6                                        FABIO NIEVES,            13
# 7                                          Petitioner,            11
# 8    v.                                            ...            87
# 9                             SECRETARY, DEPARTMENT OF            24
# 10                                CORRECTIONS, et al.,            20
# 11                                        Respondents.            12
# 12                                               ORDER             5
# 13   Petitioner initiated this action for habeas co...            87
# 14   2254 (Doc. No. 1). Respondents filed a respons...            87
# 15   Court's instructions and with the Rules Govern...            89
# 16   District Courts (Doc. No. 9). Petitioner filed...            91
# 17                                (Doc. Nos. 12 & 14).            20
# 18   Petitioner alleges one claim for relief in his...            82
# 19                  demonstrates his actual innocence.            34
# 20                            I.    Procedural History            24
# 21   Petitioner was charged by indictment with one ...            82
# 22   trial was conducted in May of 1999, after whic...            87
# 23   The state trial court sentenced Petitioner to ...            85
# 24   appealed, and the Fifth District Court of Appe...            89
# 25   Nieves v. State, 739 So. 2d 125 (Fla. 5th DCA ...            93
# 26   which was denied on August 17, 1999. (App. A a...            88
# 27   discretionary jurisdiction of the Supreme Cour...            87
# 28                        January 18, 2000. Id. at 88.            28
# 29   Petitioner filed a Florida Rule of Criminal Pr...            76
# ..                                                 ...           ...
# 292  Sierraâs confession . . . it would not chang...            61
# 293  Defendant could still have been convicted of f...            57
# 294  murder as a principal. Furthermore, there is n...            58
# 295  probability that it would support a self-defen...            59
# 296  would be inconsistent with Defendantâs own s...            63
# 297  victim was lying on his back on the pavement w...            59
# 298  fired three shots at him. It would also be inc...            64
# 299  testimony of eyewitnesses Joseph Wexler and Bruno            49
# 300  Goncalves, who asserted that Defendant walked ...            59
# 301  the victim after others who had been fighting ...            58
# 302                caused him to end up on the ground.            35
# 303                     Id. at 88 (citations omitted).            30
# 304  Upon review of the record, the Court concludes...            76
# 305  demonstrate by clear and convincing evidence t...            86
# 306  unreasonable in light of the evidence presente...            88
# 307  demonstrated that the state courtâs determin...            93
# 308  application of, federal law. Accordingly, this...            88
# 309                                           2254(d).             8
# 310  Any of Petitionerâs allegations not specific...            86
# 311                                  be without merit.            17
# 312    Accordingly, it is hereby ORDERED AND ADJUDGED:            47
# 313  1.      The Petition for Writ of Habeas Corpus...            84
# 314  DENIED, and this case is DISMISSED WITH PREJUD...            50
# 315  2.      The Clerk of the Court shall enter jud...            82
# 316                                   close this case.            16
# 319  DONE AND ORDERED at Orlando, Florida, this 20t...            68
# 320                                         Copies to:            10
# 321                                            sc 8/20             7
# 322                                       Fabio Nieves            12
# 323                                  Counsel of Record            17
#
# [309 rows x 4 columns]

# %%
def startWithRoman (Instr):
    """
    this function return true if the given string starts with Simple Roman numeral followed by period or ' '
    """
    return re.match('^(?=[MDCLXVI])M*(C[MD]|D?C*)(X[CL]|L?X*)(I[XV]|V?I*)[ |.]',Instr) is not None

#######################################
def leadingWhiteSpace(Instr):
    """
    this function return true if the given string starts with WhiteSpace character
    """
    return re.match('^\s',Instr) is not None

########################################
def ellipses(Instr):
    """
    this function return true if the given string contains ellipses
    """
    return re.search(r'(\w+)\.{3,}',Instr) is not None

# %%
# LeadingAsterisk
parser['LeadingAsterisk'] = parser['section'].apply(str.startswith, args='*') 

    # # leading arabic numeral
ArabicNumeral= parser['section'].str.lstrip(' ').str[0].apply(str.isdigit)
    # # leading Roman numeral
RomanNumerals= parser['section'].str.lstrip(' ').apply(lambda st: startWithRoman(st))
# leadingNumeral 
parser['LeadingNumeral'] = ArabicNumeral | RomanNumerals

# endsInPeriod
parser['endsInPeriod'] = parser['section'].apply(str.endswith, args='.') 

# leadingWhiteSpace
parser['leadingWhiteSpace'] = parser['section'].apply(lambda st: leadingWhiteSpace(st))

# percentCaps #presentation precision = 2
parser['percentCaps'] = parser['section'].apply(lambda st: round(sum(1 for c in st if c.isupper())*100/len(st),2))

# ellipses
parser['ellipses'] = parser['section'].apply(lambda st: ellipses(st))

# %%
parser
# Out:
#      is_header        section_type  \
# 0        False                None
# 1        False                None
# 2        False                None
# 3        False                None
# 4        False                None
# 5        False                None
# 6        False                None
# 7        False                None
# 8        False                None
# 9        False                None
# 10       False                None
# 11       False                None
# 12        True               TITLE
# 13       False                None
# 14       False                None
# 15       False                None
# 16       False                None
# 17       False                None
# 18       False                NONE
# 19       False                None
# 20        True  Procedural History
# 21       False                NONE
# 22       False                None
# 23       False                None
# 24       False                None
# 25       False                None
# 26       False                None
# 27       False                None
# 28       False                None
# 29       False                NONE
# ..         ...                 ...
# 292      False                None
# 293      False                None
# 294      False                None
# 295      False                None
# 296      False                None
# 297      False                None
# 298      False                None
# 299      False                None
# 300      False                None
# 301      False                None
# 302      False                None
# 303      False                None
# 304      False                NONE
# 305      False                None
# 306      False                None
# 307      False                None
# 308      False                None
# 309      False                None
# 310      False                NONE
# 311      False                None
# 312      False                NONE
# 313      False                None
# 314      False                None
# 315      False                None
# 316      False                None
# 319      False                NONE
# 320      False                None
# 321      False                None
# 322      False                None
# 323      False                None
#
#                                                section  stringLength  \
# 0                             Nieves v. Secretary, DOC            24
# 1                                          Description            11
# 2    ORDER denying  1  Petition for writ of habeas ...           212
# 3                         UNITED STATES DISTRICT COURT            28
# 4                           MIDDLE DISTRICT OF FLORIDA            26
# 5                                     ORLANDO DIVISION            16
# 6                                        FABIO NIEVES,            13
# 7                                          Petitioner,            11
# 8    v.                                            ...            87
# 9                             SECRETARY, DEPARTMENT OF            24
# 10                                CORRECTIONS, et al.,            20
# 11                                        Respondents.            12
# 12                                               ORDER             5
# 13   Petitioner initiated this action for habeas co...            87
# 14   2254 (Doc. No. 1). Respondents filed a respons...            87
# 15   Court's instructions and with the Rules Govern...            89
# 16   District Courts (Doc. No. 9). Petitioner filed...            91
# 17                                (Doc. Nos. 12 & 14).            20
# 18   Petitioner alleges one claim for relief in his...            82
# 19                  demonstrates his actual innocence.            34
# 20                            I.    Procedural History            24
# 21   Petitioner was charged by indictment with one ...            82
# 22   trial was conducted in May of 1999, after whic...            87
# 23   The state trial court sentenced Petitioner to ...            85
# 24   appealed, and the Fifth District Court of Appe...            89
# 25   Nieves v. State, 739 So. 2d 125 (Fla. 5th DCA ...            93
# 26   which was denied on August 17, 1999. (App. A a...            88
# 27   discretionary jurisdiction of the Supreme Cour...            87
# 28                        January 18, 2000. Id. at 88.            28
# 29   Petitioner filed a Florida Rule of Criminal Pr...            76
# ..                                                 ...           ...
# 292  Sierraâs confession . . . it would not chang...            61
# 293  Defendant could still have been convicted of f...            57
# 294  murder as a principal. Furthermore, there is n...            58
# 295  probability that it would support a self-defen...            59
# 296  would be inconsistent with Defendantâs own s...            63
# 297  victim was lying on his back on the pavement w...            59
# 298  fired three shots at him. It would also be inc...            64
# 299  testimony of eyewitnesses Joseph Wexler and Bruno            49
# 300  Goncalves, who asserted that Defendant walked ...            59
# 301  the victim after others who had been fighting ...            58
# 302                caused him to end up on the ground.            35
# 303                     Id. at 88 (citations omitted).            30
# 304  Upon review of the record, the Court concludes...            76
# 305  demonstrate by clear and convincing evidence t...            86
# 306  unreasonable in light of the evidence presente...            88
# 307  demonstrated that the state courtâs determin...            93
# 308  application of, federal law. Accordingly, this...            88
# 309                                           2254(d).             8
# 310  Any of Petitionerâs allegations not specific...            86
# 311                                  be without merit.            17
# 312    Accordingly, it is hereby ORDERED AND ADJUDGED:            47
# 313  1.      The Petition for Writ of Habeas Corpus...            84
# 314  DENIED, and this case is DISMISSED WITH PREJUD...            50
# 315  2.      The Clerk of the Court shall enter jud...            82
# 316                                   close this case.            16
# 319  DONE AND ORDERED at Orlando, Florida, this 20t...            68
# 320                                         Copies to:            10
# 321                                            sc 8/20             7
# 322                                       Fabio Nieves            12
# 323                                  Counsel of Record            17
#
#      LeadingAsterisk  LeadingNumeral  endsInPeriod  leadingWhiteSpace  \
# 0              False           False         False              False
# 1              False           False         False              False
# 2              False           False         False              False
# 3              False           False         False              False
# 4              False           False         False              False
# 5              False           False         False              False
# 6              False           False         False              False
# 7              False           False         False              False
# 8              False           False         False              False
# 9              False           False         False              False
# 10             False           False         False              False
# 11             False           False          True              False
# 12             False           False         False              False
# 13             False           False         False              False
# 14             False            True         False              False
# 15             False           False         False              False
# 16             False           False         False              False
# 17             False           False          True              False
# 18             False           False         False              False
# 19             False           False          True              False
# 20             False            True         False              False
# 21             False           False         False              False
# 22             False           False          True              False
# 23             False           False         False              False
# 24             False           False         False              False
# 25             False           False         False              False
# 26             False           False         False              False
# 27             False           False         False              False
# 28             False           False          True              False
# 29             False           False         False              False
# ..               ...             ...           ...                ...
# 292            False           False         False              False
# 293            False           False         False              False
# 294            False           False         False              False
# 295            False           False         False              False
# 296            False           False         False              False
# 297            False           False         False              False
# 298            False           False         False              False
# 299            False           False         False              False
# 300            False           False         False              False
# 301            False           False         False              False
# 302            False           False          True              False
# 303            False           False          True              False
# 304            False           False         False              False
# 305            False           False         False              False
# 306            False           False         False              False
# 307            False           False         False              False
# 308            False           False         False              False
# 309            False            True          True              False
# 310            False           False         False              False
# 311            False           False          True              False
# 312            False           False         False              False
# 313            False            True         False              False
# 314            False           False          True              False
# 315            False            True         False              False
# 316            False           False          True              False
# 319            False           False          True              False
# 320            False           False         False              False
# 321            False           False         False              False
# 322            False           False         False              False
# 323            False           False         False              False
#
#      percentCaps  ellipses
# 0          20.83     False
# 1           9.09     False
# 2           6.60     False
# 3          89.29     False
# 4          88.46     False
# 5          93.75     False
# 6          84.62     False
# 7           9.09     False
# 8          11.49     False
# 9          87.50     False
# 10         55.00     False
# 11          8.33     False
# 12        100.00     False
# 13          4.60     False
# 14          3.45     False
# 15          7.87     False
# 16          5.49     False
# 17         10.00     False
# 18          1.22     False
# 19          0.00     False
# 20         12.50     False
# 21          2.44     False
# 22          2.30     False
# 23          3.53     False
# 24          7.87     False
# 25          8.60     False
# 26          4.55     False
# 27          3.45     False
# 28          7.14     False
# 29          6.58     False
# ..           ...       ...
# 292         1.64     False
# 293         1.75     False
# 294         1.72     False
# 295         1.69     False
# 296         1.59     False
# 297         1.69     False
# 298         1.56     False
# 299         6.12     False
# 300         3.39     False
# 301         0.00     False
# 302         0.00     False
# 303         3.33     False
# 304         3.95     False
# 305         0.00     False
# 306         2.27     False
# 307         0.00     False
# 308         2.27     False
# 309         0.00     False
# 310         2.33     False
# 311         0.00     False
# 312        40.43     False
# 313        10.71     False
# 314        56.00     False
# 315         3.66     False
# 316         0.00     False
# 319        25.00     False
# 320        10.00     False
# 321         0.00     False
# 322        16.67     False
# 323        11.76     False
#
# [309 rows x 10 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=parser.iloc[:,3:10].values
Y=parser.iloc[:,0].values

# %%
#splitting test set to training set and test set
from sklearn.cross_validation import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=0.3, random_state=0)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#feaure scaling
from sklearn.preprocessing import StandardScaler
sc_X= StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#fiting logistic regression to the training set
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#predict the test set result
Y_pred=classifier.predict(X_test)

# %%
#making confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,Y_pred)
print(cm)
# Out:
# [[90  0]
#  [ 3  0]]

# %%
#visualising the training set result
